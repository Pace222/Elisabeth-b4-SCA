# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning

# %%
if True:
    with open("splitted_round_2.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_round_2_adjusted_only.pic", "rb") as r:
        traces_round_2 = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_round_2, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_round_2.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_round_2", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_round_2_adjusted.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_round_2_adjusted.keras")
except ValueError:
    pass

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_round_2_adjusted.keras", patience=10)
# Out:
# Epoch 1/1000
# 10547/10547 [==============================] - 1999s 189ms/step - loss: 39.2628 - block_perm_2_output_loss: 0.9676 - mask_2_0_0_output_loss: 2.7341 - mask_2_0_1_output_loss: 2.7253 - mask_2_1_0_output_loss: 2.7401 - mask_2_1_1_output_loss: 2.7329 - mask_2_2_0_output_loss: 2.7422 - mask_2_2_1_output_loss: 2.7354 - mask_2_3_0_output_loss: 2.7415 - mask_2_3_1_output_loss: 2.7357 - mask_2_4_0_output_loss: 2.7386 - mask_2_4_1_output_loss: 2.7337 - mask_2_5_0_output_loss: 2.7370 - mask_2_5_1_output_loss: 2.7302 - mask_2_6_0_output_loss: 2.7352 - mask_2_6_1_output_loss: 2.7332 - block_perm_2_output_accuracy: 0.7013 - mask_2_0_0_output_accuracy: 0.0931 - mask_2_0_1_output_accuracy: 0.0980 - mask_2_1_0_output_accuracy: 
output_accuracy: 0.0939 - mask_2_5_0_output_accuracy: 0.0908 - mask_2_5_1_output_accuracy: 0.0952 - mask_2_6_0_output_accuracy: 0.0918 - mask_2_6_1_output_accuracy: 0.0934 - val_loss: 41.5780 - val_block_perm_2_output_loss: 1.4318 - val_mask_2_0_0_output_loss: 3.0038 - val_mask_2_0_1_output_loss: 2.9311 - val_mask_2_1_0_output_loss: 2.7822 - val_mask_2_1_1_output_loss: 2.7650 - val_mask_2_2_0_output_loss: 2.9203 - val_mask_2_2_1_output_loss: 2.8589 - val_mask_2_3_0_output_loss: 2.7512 - val_mask_2_3_1_output_loss: 2.7691 - val_mask_2_4_0_output_loss: 2.7522 - val_mask_2_4_1_output_loss: 2.7611 - val_mask_2_5_0_output_loss: 2.8253 - val_mask_2_5_1_output_loss: 3.3329 - val_mask_2_6_0_output_loss: 2.7803 - val_mask_2_6_1_output_loss: 2.9128 - val_block_perm_2_output_accuracy: 0.5105 - val_mask_2_0_0_output_accuracy: 0.0638 - val_mask_2_0_1_output_accuracy: 0.0714 - val_mask_2_1_0_output_accuracy: 0.0803 - val_mask_2_1_1_output_accuracy: 0.0914 - val_mask_2_2_0_output_accuracy: 0.0644 - val_mask_2_2_1_output_accuracy: 0.0712 - val_mask_2_3_0_output_accuracy: 0.0840 - val_mask_2_3_1_output_accuracy: 0.0828 - val_mask_2_4_0_output_accuracy: 0.0798 - val_mask_2_4_1_output_accuracy: 0.0871 - val_mask_2_5_0_output_accuracy: 0.0743 - val_mask_2_5_1_output_accuracy: 0.0652 - val_mask_2_6_0_output_accuracy: 0.0775 - val_mask_2_6_1_output_accuracy: 0.0696
# Epoch 5/1000
# 10547/10547 [==============================] - 1984s 188ms/step - loss: 39.2300 - block_perm_2_output_loss: 0.9527 - mask_2_0_0_output_loss: 2.7330 - mask_2_0_1_output_loss: 2.7234 - mask_2_1_0_output_loss: 2.7393 - mask_2_1_1_output_loss: 2.7313 - mask_2_2_0_output_loss: 2.7411 - mask_2_2_1_output_loss: 2.7337 - mask_2_3_0_output_loss: 2.7407 - mask_2_3_1_output_loss: 2.7342 - mask_2_4_0_output_loss: 2.7375 - mask_2_4_1_output_loss: 2.7324 - mask_2_5_0_output_loss: 2.7361 - mask_2_5_1_output_loss: 2.7287 - mask_2_6_0_output_loss: 2.7341 - mask_2_6_1_output_loss: 2.7319 - block_perm_2_output_accuracy: 0.7056 - mask_2_0_0_output_accuracy: 0.0929 - mask_2_0_1_output_accuracy: 0.0987 - mask_2_1_0_output_accuracy: 0.0906 - mask_2_1_1_output_accuracy: 0.0944 - mask_2_2_0_output_accuracy: 0.0890 - mask_2_2_1_output_accuracy: 0.0938 - mask_2_3_0_output_accuracy: 0.0890 - mask_2_3_1_output_accuracy: 0.0941 - mask_2_4_0_output_accuracy: 0.0902 - mask_2_4_1_output_accuracy: 0.0941 - mask_2_5_0_output_accuracy: 0.0914 - mask_2_5_1_output_accuracy: 0.0956 - mask_2_6_0_output_accuracy: 0.0919 - mask_2_6_1_output_accuracy: 0.0936 - val_loss: 40.2875 - val_block_perm_2_output_loss: 1.2530 - val_mask_2_0_0_output_loss: 2.7948 - val_mask_2_0_1_output_loss: 2.8143 - val_mask_2_1_0_output_loss: 2.8707 - val_mask_2_1_1_output_loss: 2.7765 - val_mask_2_2_0_output_loss: 2.7777 - val_mask_2_2_1_output_loss: 2.7710 - val_mask_2_3_0_output_loss: 2.7577 - val_mask_2_3_1_output_loss: 2.7395 - val_mask_2_4_0_output_loss: 2.7695 - val_mask_2_4_1_output_loss: 2.7346 - val_mask_2_5_0_output_loss: 2.8490 - val_mask_2_5_1_output_loss: 2.8465 - val_mask_2_6_0_output_loss: 2.7629 - val_mask_2_6_1_output_loss: 2.7697 - val_block_perm_2_output_accuracy: 0.6028 - val_mask_2_0_0_output_accuracy: 0.0806 - val_mask_2_0_1_output_accuracy: 0.0738 - val_mask_2_1_0_output_accuracy: 0.0690 - val_mask_2_1_1_output_accuracy: 0.0802 - val_mask_2_2_0_output_accuracy: 0.0784 - val_mask_2_2_1_output_accuracy: 0.0835 - val_mask_2_3_0_output_accuracy: 0.0846 - val_mask_2_3_1_output_accuracy: 0.0910 - val_mask_2_4_0_output_accuracy: 0.0783 - val_mask_2_4_1_output_accuracy: 0.0910 - val_mask_2_5_0_output_accuracy: 0.0736 - val_mask_2_5_1_output_accuracy: 0.0726 - val_mask_2_6_0_output_accuracy: 0.0847 - val_mask_2_6_1_output_accuracy: 0.0833
# Epoch 6/1000
#    93/10547 [..............................] - ETA: 30:59 - loss: 39.1732 - block_perm_2_output_loss: 0.9235 - mask_2_0_0_output_loss: 2.7302 - mask_2_0_1_output_loss: 2.7232 - mask_2_1_0_output_loss: 2.7345 - mask_2_1_1_output_loss: 2.7280 - mask_2_2_0_output_loss: 2.7423 - mask_2_2_1_output_loss: 2.7302 - mask_2_3_0_output_loss: 2.7347 - mask_2_3_1_output_loss: 2.7363 - mask_2_4_0_output_loss: 2.7413 - mask_2_4_1_output_loss: 2.7311 - mask_2_5_0_output_loss: 2.7315 - mask_2_5_1_output_loss: 2.7256 - mask_2_6_0_output_loss: 2.7294 - mask_2_6_1_output_loss: 2.7314 - block_perm_2_output_accuracy: 0.7156 - mask_2_0_0_output_accuracy: 0.0924 - mask_2_0_1_output_accuracy: 0.0980 - mask_2_1_0_output_accuracy: 0.0961 - mask_2_1_1_output_accuracy: 0.0959 - mask_2_2_0_output_accuracy: 0.0916 - mask_2_2_1_output_accuracy: 0.0954 - mask_2_3_0_output_accuracy: 0.0968 - mask_2_3_1_output_accuracy: 0.0916 - mask_2_4_0_output_accuracy: 0.0907 - mask_2_4_1_output_accuracy: 0.0968 - mask_2_5_0_output_accuracy: 0.0895 - mask_2_5_1_output_accuracy: 0.0980 - mask_2_6_0_output_accuracy: 0.0991 - mask_2_6_1_output_accuracy: 0.0909
