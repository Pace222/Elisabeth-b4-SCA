# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "4"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning
# Out:
# 2024-06-11 17:10:26.801220: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-11 17:10:26.858810: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-11 17:10:27.839709: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
if True:
    with open("splitted_round_12.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_round_12_adjusted_only.pic", "rb") as r:
        traces_round_12 = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_round_12, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_round_12.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_round_12", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_round_12_adjusted.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_round_12_adjusted.keras")
except ValueError:
    pass
# Out:
# 2024-06-11 17:10:32.499251: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.542824: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.542884: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.555176: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.555243: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.555274: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.773874: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.773936: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.773946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-11 17:10:32.773987: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-11 17:10:32.774014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9057 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_round_12_adjusted.keras", patience=10)
# Out:
# Epoch 1/1000
# 2024-06-11 17:10:56.351579: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# /root/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718118656.604626    5582 service.cc:145] XLA service 0x7f2d100765b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1718118656.604681    5582 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-06-11 17:10:57.431638: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-11 17:11:00.358438: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-06-11 17:11:03.905948: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 12.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718118675.159392    5582 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_40', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1718118675.197669    5582 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  3140/10547 ━━━━━━━━━━━━━━━━━━━━ 7:20 60ms/step - block_perm_12_output_accuracy: 0.1596 - loss: 41.4373 - mask_12_0_0_output_accuracy: 0.0625 - mask_12_0_1_output_accuracy: 0.0619 - mask_12_1_0_output_accuracy: 0.0624 - mask_12_1_1_output_accuracy: 0.0616 - mask_12_2_0_output_accuracy: 0.0632 - mask_12_2_1_output_accuracy: 0.0628 - mask_12_3_0_output_accuracy: 0.0633 - mask_12_3_1_output_accuracy: 0.0617 - mask_12_4_0_output_accuracy: 0.0632 - mask_12_4_1_output_accuracy: 0.0625 - mask_12_5_0_output_accuracy: 0.0624 - mask_12_5_1_output_accuracy: 0.0621 - mask_12_6_0_output_accuracy: 0.0629 - mask_12_6_1_output_accuracy: 0.0615
# 2024-06-11 17:14:28.590632: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 11.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1718118880.828208    5582 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 120 bytes spill stores, 120 bytes spill loads
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 713s 64ms/step - block_perm_12_output_accuracy: 0.1890 - loss: 41.2922 - mask_12_0_0_output_accuracy: 0.0626 - mask_12_0_1_output_accuracy: 0.0626 - mask_12_1_0_output_accuracy: 0.0627 - mask_12_1_1_output_accuracy: 0.0624 - mask_12_2_0_output_accuracy: 0.0631 - mask_12_2_1_output_accuracy: 0.0629 - mask_12_3_0_output_accuracy: 0.0628 - mask_12_3_1_output_accuracy: 0.0624 - mask_12_4_0_output_accuracy: 0.0630 - mask_12_4_1_output_accuracy: 0.0624 - mask_12_5_0_output_accuracy: 0.0622 - mask_12_5_1_output_accuracy: 0.0621 - mask_12_6_0_output_accuracy: 0.0627 - mask_12_6_1_output_accuracy: 0.0621 - val_block_perm_12_output_accuracy: 0.3672 - val_loss: 41.4133 - val_mask_12_0_0_output_accuracy: 0.0622 - val_mask_12_0_1_output_accuracy: 0.0627 - val_mask_12_1_0_output_accuracy: 0.0646 - val_mask_12_1_1_output_accuracy: 0.0667 - val_mask_12_2_0_output_accuracy: 0.0648 - val_mask_12_2_1_output_accuracy: 0.0650 - val_mask_12_3_0_output_accuracy: 0.0623 - val_mask_12_3_1_output_accuracy: 0.0626 - val_mask_12_4_0_output_accuracy: 0.0681 - val_mask_12_4_1_output_accuracy: 0.0643 - val_mask_12_5_0_output_accuracy: 0.0636 - val_mask_12_5_1_output_accuracy: 0.0663 - val_mask_12_6_0_output_accuracy: 0.0651 - val_mask_12_6_1_output_accuracy: 0.0638
# Epoch 2/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 645s 61ms/step - block_perm_12_output_accuracy: 0.5290 - loss: 40.3979 - mask_12_0_0_output_accuracy: 0.0694 - mask_12_0_1_output_accuracy: 0.0698 - mask_12_1_0_output_accuracy: 0.0751 - mask_12_1_1_output_accuracy: 0.0760 - mask_12_2_0_output_accuracy: 0.0732 - mask_12_2_1_output_accuracy: 0.0759 - mask_12_3_0_output_accuracy: 0.0724 - mask_12_3_1_output_accuracy: 0.0734 - mask_12_4_0_output_accuracy: 0.0721 - mask_12_4_1_output_accuracy: 0.0738 - mask_12_5_0_output_accuracy: 0.0729 - mask_12_5_1_output_accuracy: 0.0747 - mask_12_6_0_output_accuracy: 0.0755 - mask_12_6_1_output_accuracy: 0.0742 - val_block_perm_12_output_accuracy: 0.2645 - val_loss: 41.9294 - val_mask_12_0_0_output_accuracy: 0.0834 - val_mask_12_0_1_output_accuracy: 0.0840 - val_mask_12_1_0_output_accuracy: 0.0762 - val_mask_12_1_1_output_accuracy: 0.0769 - val_mask_12_2_0_output_accuracy: 0.0741 - val_mask_12_2_1_output_accuracy: 0.0767 - val_mask_12_3_0_output_accuracy: 0.0833 - val_mask_12_3_1_output_accuracy: 0.0836 - val_mask_12_4_0_output_accuracy: 0.0735 - val_mask_12_4_1_output_accuracy: 0.0805 - val_mask_12_5_0_output_accuracy: 0.0821 - val_mask_12_5_1_output_accuracy: 0.0780 - val_mask_12_6_0_output_accuracy: 0.0831 - val_mask_12_6_1_output_accuracy: 0.0843
# Epoch 3/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 648s 61ms/step - block_perm_12_output_accuracy: 0.6439 - loss: 39.6747 - mask_12_0_0_output_accuracy: 0.0843 - mask_12_0_1_output_accuracy: 0.0864 - mask_12_1_0_output_accuracy: 0.0840 - mask_12_1_1_output_accuracy: 0.0861 - mask_12_2_0_output_accuracy: 0.0856 - mask_12_2_1_output_accuracy: 0.0874 - mask_12_3_0_output_accuracy: 0.0847 - mask_12_3_1_output_accuracy: 0.0860 - mask_12_4_0_output_accuracy: 0.0840 - mask_12_4_1_output_accuracy: 0.0859 - mask_12_5_0_output_accuracy: 0.0828 - mask_12_5_1_output_accuracy: 0.0864 - mask_12_6_0_output_accuracy: 0.0863 - mask_12_6_1_output_accuracy: 0.0872 - val_block_perm_12_output_accuracy: 0.4264 - val_loss: 41.1665 - val_mask_12_0_0_output_accuracy: 0.0679 - val_mask_12_0_1_output_accuracy: 0.0764 - val_mask_12_1_0_output_accuracy: 0.0845 - val_mask_12_1_1_output_accuracy: 0.0869 - val_mask_12_2_0_output_accuracy: 0.0862 - val_mask_12_2_1_output_accuracy: 0.0890 - val_mask_12_3_0_output_accuracy: 0.0872 - val_mask_12_3_1_output_accuracy: 0.0825 - val_mask_12_4_0_output_accuracy: 0.0755 - val_mask_12_4_1_output_accuracy: 0.0855 - val_mask_12_5_0_output_accuracy: 0.0642 - val_mask_12_5_1_output_accuracy: 0.0627 - val_mask_12_6_0_output_accuracy: 0.0683 - val_mask_12_6_1_output_accuracy: 0.0678
# Epoch 4/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 650s 62ms/step - block_perm_12_output_accuracy: 0.6696 - loss: 39.4442 - mask_12_0_0_output_accuracy: 0.0881 - mask_12_0_1_output_accuracy: 0.0915 - mask_12_1_0_output_accuracy: 0.0861 - mask_12_1_1_output_accuracy: 0.0893 - mask_12_2_0_output_accuracy: 0.0868 - mask_12_2_1_output_accuracy: 0.0892 - mask_12_3_0_output_accuracy: 0.0870 - mask_12_3_1_output_accuracy: 0.0895 - mask_12_4_0_output_accuracy: 0.0882 - mask_12_4_1_output_accuracy: 0.0895 - mask_12_5_0_output_accuracy: 0.0865 - mask_12_5_1_output_accuracy: 0.0894 - mask_12_6_0_output_accuracy: 0.0881 - mask_12_6_1_output_accuracy: 0.0884 - val_block_perm_12_output_accuracy: 0.5625 - val_loss: 40.1532 - val_mask_12_0_0_output_accuracy: 0.0828 - val_mask_12_0_1_output_accuracy: 0.0845 - val_mask_12_1_0_output_accuracy: 0.0806 - val_mask_12_1_1_output_accuracy: 0.0840 - val_mask_12_2_0_output_accuracy: 0.0843 - val_mask_12_2_1_output_accuracy: 0.0850 - val_mask_12_3_0_output_accuracy: 0.0746 - val_mask_12_3_1_output_accuracy: 0.0826 - val_mask_12_4_0_output_accuracy: 0.0807 - val_mask_12_4_1_output_accuracy: 0.0792 - val_mask_12_5_0_output_accuracy: 0.0729 - val_mask_12_5_1_output_accuracy: 0.0749 - val_mask_12_6_0_output_accuracy: 0.0832 - val_mask_12_6_1_output_accuracy: 0.0889
# Epoch 5/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 648s 61ms/step - block_perm_12_output_accuracy: 0.6814 - loss: 39.3842 - mask_12_0_0_output_accuracy: 0.0898 - mask_12_0_1_output_accuracy: 0.0930 - mask_12_1_0_output_accuracy: 0.0871 - mask_12_1_1_output_accuracy: 0.0912 - mask_12_2_0_output_accuracy: 0.0874 - mask_12_2_1_output_accuracy: 0.0904 - mask_12_3_0_output_accuracy: 0.0877 - mask_12_3_1_output_accuracy: 0.0904 - mask_12_4_0_output_accuracy: 0.0879 - mask_12_4_1_output_accuracy: 0.0908 - mask_12_5_0_output_accuracy: 0.0871 - mask_12_5_1_output_accuracy: 0.0918 - mask_12_6_0_output_accuracy: 0.0884 - mask_12_6_1_output_accuracy: 0.0892 - val_block_perm_12_output_accuracy: 0.5458 - val_loss: 40.0344 - val_mask_12_0_0_output_accuracy: 0.0871 - val_mask_12_0_1_output_accuracy: 0.0910 - val_mask_12_1_0_output_accuracy: 0.0821 - val_mask_12_1_1_output_accuracy: 0.0890 - val_mask_12_2_0_output_accuracy: 0.0861 - val_mask_12_2_1_output_accuracy: 0.0851 - val_mask_12_3_0_output_accuracy: 0.0669 - val_mask_12_3_1_output_accuracy: 0.0699 - val_mask_12_4_0_output_accuracy: 0.0828 - val_mask_12_4_1_output_accuracy: 0.0884 - val_mask_12_5_0_output_accuracy: 0.0780 - val_mask_12_5_1_output_accuracy: 0.0890 - val_mask_12_6_0_output_accuracy: 0.0875 - val_mask_12_6_1_output_accuracy: 0.0824
# Epoch 6/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 649s 62ms/step - block_perm_12_output_accuracy: 0.6871 - loss: 39.3503 - mask_12_0_0_output_accuracy: 0.0905 - mask_12_0_1_output_accuracy: 0.0942 - mask_12_1_0_output_accuracy: 0.0875 - mask_12_1_1_output_accuracy: 0.0910 - mask_12_2_0_output_accuracy: 0.0882 - mask_12_2_1_output_accuracy: 0.0907 - mask_12_3_0_output_accuracy: 0.0890 - mask_12_3_1_output_accuracy: 0.0910 - mask_12_4_0_output_accuracy: 0.0889 - mask_12_4_1_output_accuracy: 0.0914 - mask_12_5_0_output_accuracy: 0.0880 - mask_12_5_1_output_accuracy: 0.0928 - mask_12_6_0_output_accuracy: 0.0893 - mask_12_6_1_output_accuracy: 0.0903 - val_block_perm_12_output_accuracy: 0.5644 - val_loss: 39.8357 - val_mask_12_0_0_output_accuracy: 0.0899 - val_mask_12_0_1_output_accuracy: 0.0942 - val_mask_12_1_0_output_accuracy: 0.0848 - val_mask_12_1_1_output_accuracy: 0.0924 - val_mask_12_2_0_output_accuracy: 0.0746 - val_mask_12_2_1_output_accuracy: 0.0777 - val_mask_12_3_0_output_accuracy: 0.0759 - val_mask_12_3_1_output_accuracy: 0.0837 - val_mask_12_4_0_output_accuracy: 0.0840 - val_mask_12_4_1_output_accuracy: 0.0892 - val_mask_12_5_0_output_accuracy: 0.0856 - val_mask_12_5_1_output_accuracy: 0.0911 - val_mask_12_6_0_output_accuracy: 0.0896 - val_mask_12_6_1_output_accuracy: 0.0901
# Epoch 7/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 647s 61ms/step - block_perm_12_output_accuracy: 0.6929 - loss: 39.3231 - mask_12_0_0_output_accuracy: 0.0911 - mask_12_0_1_output_accuracy: 0.0948 - mask_12_1_0_output_accuracy: 0.0877 - mask_12_1_1_output_accuracy: 0.0927 - mask_12_2_0_output_accuracy: 0.0885 - mask_12_2_1_output_accuracy: 0.0914 - mask_12_3_0_output_accuracy: 0.0894 - mask_12_3_1_output_accuracy: 0.0916 - mask_12_4_0_output_accuracy: 0.0891 - mask_12_4_1_output_accuracy: 0.0919 - mask_12_5_0_output_accuracy: 0.0888 - mask_12_5_1_output_accuracy: 0.0929 - mask_12_6_0_output_accuracy: 0.0886 - mask_12_6_1_output_accuracy: 0.0905 - val_block_perm_12_output_accuracy: 0.5776 - val_loss: 40.2997 - val_mask_12_0_0_output_accuracy: 0.0663 - val_mask_12_0_1_output_accuracy: 0.0849 - val_mask_12_1_0_output_accuracy: 0.0766 - val_mask_12_1_1_output_accuracy: 0.0789 - val_mask_12_2_0_output_accuracy: 0.0877 - val_mask_12_2_1_output_accuracy: 0.0883 - val_mask_12_3_0_output_accuracy: 0.0857 - val_mask_12_3_1_output_accuracy: 0.0908 - val_mask_12_4_0_output_accuracy: 0.0875 - val_mask_12_4_1_output_accuracy: 0.0913 - val_mask_12_5_0_output_accuracy: 0.0706 - val_mask_12_5_1_output_accuracy: 0.0690 - val_mask_12_6_0_output_accuracy: 0.0688 - val_mask_12_6_1_output_accuracy: 0.0765
# Epoch 8/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 649s 62ms/step - block_perm_12_output_accuracy: 0.6960 - loss: 39.3016 - mask_12_0_0_output_accuracy: 0.0910 - mask_12_0_1_output_accuracy: 0.0948 - mask_12_1_0_output_accuracy: 0.0887 - mask_12_1_1_output_accuracy: 0.0932 - mask_12_2_0_output_accuracy: 0.0890 - mask_12_2_1_output_accuracy: 0.0924 - mask_12_3_0_output_accuracy: 0.0901 - mask_12_3_1_output_accuracy: 0.0933 - mask_12_4_0_output_accuracy: 0.0896 - mask_12_4_1_output_accuracy: 0.0925 - mask_12_5_0_output_accuracy: 0.0893 - mask_12_5_1_output_accuracy: 0.0934 - mask_12_6_0_output_accuracy: 0.0896 - mask_12_6_1_output_accuracy: 0.0904 - val_block_perm_12_output_accuracy: 0.6564 - val_loss: 39.7976 - val_mask_12_0_0_output_accuracy: 0.0777 - val_mask_12_0_1_output_accuracy: 0.0858 - val_mask_12_1_0_output_accuracy: 0.0827 - val_mask_12_1_1_output_accuracy: 0.0878 - val_mask_12_2_0_output_accuracy: 0.0863 - val_mask_12_2_1_output_accuracy: 0.0900 - val_mask_12_3_0_output_accuracy: 0.0892 - val_mask_12_3_1_output_accuracy: 0.0846 - val_mask_12_4_0_output_accuracy: 0.0799 - val_mask_12_4_1_output_accuracy: 0.0860 - val_mask_12_5_0_output_accuracy: 0.0816 - val_mask_12_5_1_output_accuracy: 0.0735 - val_mask_12_6_0_output_accuracy: 0.0717 - val_mask_12_6_1_output_accuracy: 0.0816
# Epoch 9/1000
#  2841/10547 ━━━━━━━━━━━━━━━━━━━━ 7:43 60ms/step - block_perm_12_output_accuracy: 0.6983 - loss: 39.2838 - mask_12_0_0_output_accuracy: 0.0925 - mask_12_0_1_output_accuracy: 0.0966 - mask_12_1_0_output_accuracy: 0.0892 - mask_12_1_1_output_accuracy: 0.0924 - mask_12_2_0_output_accuracy: 0.0893 - mask_12_2_1_output_accuracy: 0.0940 - mask_12_3_0_output_accuracy: 0.0917 - mask_12_3_1_output_accuracy: 0.0919 - mask_12_4_0_output_accuracy: 0.0907 - mask_12_4_1_output_accuracy: 0.0912 - mask_12_5_0_output_accuracy: 0.0904 - mask_12_5_1_output_accuracy: 0.0936 - mask_12_6_0_output_accuracy: 0.0897 - mask_12_6_1_output_accuracy: 0.0909
