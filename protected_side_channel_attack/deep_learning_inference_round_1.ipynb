# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

path = r"C:\Users\iot-user\miniconda3\envs\tf-gpu\Lib\site-packages\nvidia\cudnn\bin"
os.environ['PATH'] += ';'+path

# %%
import numpy as np
import pickle as pic

# %%
from tensorflow.keras.models import load_model

# %%
with open("splitted_round_1.pic", "rb") as r:
    X_training, X_val, X_extraction = pic.load(r)

# %%
model = load_model("./resnet_models/resnet_750000_orig_round_1_adjusted.keras")
y_prediction = model.predict(X_extraction)
y_prediction = [np.log(pred) for pred in y_prediction]
# Out:
# 7813/7813 [==============================] - 188s 24ms/step

# %%
with open("y_extraction_750000_orig_round_1_adjusted.pic", "wb") as w:
    pic.dump(y_prediction, w)
