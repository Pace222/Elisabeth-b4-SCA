# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning

# %%
if True:
    with open("splitted_round_0.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
        X_training, X_val, X_extraction = X_training[:, :70], X_val[:, :70], X_extraction[:, :70]
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("wavelets_haar_2.pic", "rb") as r:
        wavelets = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(wavelets, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=500_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_wavelets_haar_2.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="test_mask_0_0_0", epochs=1000, dataset_size=X_training.shape[0])

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_test_mask_0_0_0.keras", patience=10)
# Out:
# Epoch 1/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7743 - accuracy: 0.0786 - val_loss: 2.8217 - val_accuracy: 0.0755
# Epoch 2/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7504 - accuracy: 0.0854 - val_loss: 2.7567 - val_accuracy: 0.0825
# Epoch 3/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7433 - accuracy: 0.0878 - val_loss: 2.9498 - val_accuracy: 0.0659
# Epoch 4/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7419 - accuracy: 0.0889 - val_loss: 2.8317 - val_accuracy: 0.0724
# Epoch 5/1000
# 10547/10547 [==============================] - 119s 11ms/step - loss: 2.7411 - accuracy: 0.0893 - val_loss: 2.8646 - val_accuracy: 0.0708
# Epoch 6/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7406 - accuracy: 0.0895 - val_loss: 2.7727 - val_accuracy: 0.0802
# Epoch 7/1000
# 10547/10547 [==============================] - 119s 11ms/step - loss: 2.7403 - accuracy: 0.0895 - val_loss: 2.8068 - val_accuracy: 0.0824
# Epoch 8/1000
# 10547/10547 [==============================] - 119s 11ms/step - loss: 2.7400 - accuracy: 0.0896 - val_loss: 2.8786 - val_accuracy: 0.0681
# Epoch 9/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7397 - accuracy: 0.0902 - val_loss: 2.7445 - val_accuracy: 0.0887
# Epoch 10/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7396 - accuracy: 0.0905 - val_loss: 3.0383 - val_accuracy: 0.0655
# Epoch 11/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7395 - accuracy: 0.0904 - val_loss: 2.7888 - val_accuracy: 0.0769
# Epoch 12/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7393 - accuracy: 0.0904 - val_loss: 2.7799 - val_accuracy: 0.0799
# Epoch 13/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7391 - accuracy: 0.0904 - val_loss: 3.0960 - val_accuracy: 0.0632
# Epoch 14/1000
# 10547/10547 [==============================] - 118s 11ms/step - loss: 2.7390 - accuracy: 0.0907 - val_loss: 2.9954 - val_accuracy: 0.0643
# Epoch 15/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7388 - accuracy: 0.0904 - val_loss: 2.7883 - val_accuracy: 0.0778
# Epoch 16/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7387 - accuracy: 0.0908 - val_loss: 2.7534 - val_accuracy: 0.0866
# Epoch 17/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7387 - accuracy: 0.0905 - val_loss: 2.8704 - val_accuracy: 0.0671
# Epoch 18/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7386 - accuracy: 0.0912 - val_loss: 2.7615 - val_accuracy: 0.0835
# Epoch 19/1000
# 10547/10547 [==============================] - 117s 11ms/step - loss: 2.7385 - accuracy: 0.0911 - val_loss: 2.8219 - val_accuracy: 0.0732

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical

y_predicted = load_model("./resnet_models/resnet_350000_52_epochs.keras").predict(X_extraction)
for i, k in enumerate(y_extraction.keys()):
    print(f"{k}: {np.count_nonzero(np.argmax(y_predicted[i], axis=1) == y_extraction[k])}/{y_extraction[k].shape[0]} = {np.count_nonzero(np.argmax(y_predicted[i], axis=1) == y_extraction[k]) / y_extraction[k].shape[0]}")

np.mean([categorical_crossentropy(to_categorical(y_extraction[k]), y_predicted[i]) for i, k in enumerate(y_extraction.keys())], axis=1)
# Out:
# 1411/1411 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step
# x_round: 24419/45133 = 0.5410453548401392
# block_perm_0: 39134/45133 = 0.8670817362018922
# mask_0_0: 354/45133 = 0.007843484811556953
# mask_0_1: 365/45133 = 0.00808720891587087
# mask_0_2: 305/45133 = 0.006757804710522234
# mask_0_3: 302/45133 = 0.006691334500254802
# mask_0_4: 332/45133 = 0.0073560366029291205
# mask_0_5: 305/45133 = 0.006757804710522234
# mask_0_6: 276/45133 = 0.006115259344603727
# array([1.3536543, 0.3749589, 5.503599 , 5.5072737, 5.477    , 5.5458245,
#        5.490437 , 5.568437 , 5.656007 ], dtype=float32)
