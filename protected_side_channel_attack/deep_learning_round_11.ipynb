# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning
# Out:
# 2024-06-12 12:10:50.927285: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-12 12:10:50.989443: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 12:10:52.057565: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
if True:
    with open("splitted_round_11.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_round_11_adjusted_only.pic", "rb") as r:
        traces_round_11 = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_round_11, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_round_11.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_round_11", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_round_11_adjusted.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_round_11_adjusted.keras")
except ValueError:
    pass
# Out:
# 2024-06-12 12:10:56.994540: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.038188: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.038245: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.051357: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.051429: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.051460: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.300645: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.300711: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.300721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-12 12:10:57.300762: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:10:57.300791: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9057 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_round_11_adjusted.keras", patience=10)
# Out:
# Epoch 1/1000
# 2024-06-12 12:11:36.277910: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# /root/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718187096.532139    7544 service.cc:145] XLA service 0x7f6030001ca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1718187096.532197    7544 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-06-12 12:11:37.343900: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-12 12:11:40.332815: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-06-12 12:11:44.159511: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 12.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718187116.428317    7544 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_40', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1718187116.469808    7544 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  1026/10547 ━━━━━━━━━━━━━━━━━━━━ 9:53 62ms/step - block_perm_11_output_accuracy: 0.7111 - loss: 39.1233 - mask_11_0_0_output_accuracy: 0.0920 - mask_11_0_1_output_accuracy: 0.0982 - mask_11_1_0_output_accuracy: 0.0891 - mask_11_1_1_output_accuracy: 0.0958 - mask_11_2_0_output_accuracy: 0.0899 - mask_11_2_1_output_accuracy: 0.0944 - mask_11_3_0_output_accuracy: 0.0883 - mask_11_3_1_output_accuracy: 0.0982 - mask_11_4_0_output_accuracy: 0.0898 - mask_11_4_1_output_accuracy: 0.0950 - mask_11_5_0_output_accuracy: 0.0941 - mask_11_5_1_output_accuracy: 0.0981 - mask_11_6_0_output_accuracy: 0.0906 - mask_11_6_1_output_accuracy: 0.0947
# 2024-06-12 12:13:06.601213: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 11.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1718187199.295701    7544 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 120 bytes spill stores, 120 bytes spill loads
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 724s 65ms/step - block_perm_11_output_accuracy: 0.7106 - loss: 39.1309 - mask_11_0_0_output_accuracy: 0.0933 - mask_11_0_1_output_accuracy: 0.0990 - mask_11_1_0_output_accuracy: 0.0895 - mask_11_1_1_output_accuracy: 0.0951 - mask_11_2_0_output_accuracy: 0.0908 - mask_11_2_1_output_accuracy: 0.0954 - mask_11_3_0_output_accuracy: 0.0906 - mask_11_3_1_output_accuracy: 0.0965 - mask_11_4_0_output_accuracy: 0.0909 - mask_11_4_1_output_accuracy: 0.0941 - mask_11_5_0_output_accuracy: 0.0915 - mask_11_5_1_output_accuracy: 0.0968 - mask_11_6_0_output_accuracy: 0.0916 - mask_11_6_1_output_accuracy: 0.0938 - val_block_perm_11_output_accuracy: 0.6002 - val_loss: 39.6367 - val_mask_11_0_0_output_accuracy: 0.0931 - val_mask_11_0_1_output_accuracy: 0.0928 - val_mask_11_1_0_output_accuracy: 0.0872 - val_mask_11_1_1_output_accuracy: 0.0928 - val_mask_11_2_0_output_accuracy: 0.0901 - val_mask_11_2_1_output_accuracy: 0.0934 - val_mask_11_3_0_output_accuracy: 0.0907 - val_mask_11_3_1_output_accuracy: 0.0920 - val_mask_11_4_0_output_accuracy: 0.0719 - val_mask_11_4_1_output_accuracy: 0.0883 - val_mask_11_5_0_output_accuracy: 0.0881 - val_mask_11_5_1_output_accuracy: 0.0943 - val_mask_11_6_0_output_accuracy: 0.0881 - val_mask_11_6_1_output_accuracy: 0.0869
# Epoch 2/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 658s 62ms/step - block_perm_11_output_accuracy: 0.7114 - loss: 39.1205 - mask_11_0_0_output_accuracy: 0.0945 - mask_11_0_1_output_accuracy: 0.0989 - mask_11_1_0_output_accuracy: 0.0903 - mask_11_1_1_output_accuracy: 0.0954 - mask_11_2_0_output_accuracy: 0.0905 - mask_11_2_1_output_accuracy: 0.0958 - mask_11_3_0_output_accuracy: 0.0911 - mask_11_3_1_output_accuracy: 0.0960 - mask_11_4_0_output_accuracy: 0.0908 - mask_11_4_1_output_accuracy: 0.0953 - mask_11_5_0_output_accuracy: 0.0909 - mask_11_5_1_output_accuracy: 0.0971 - mask_11_6_0_output_accuracy: 0.0913 - mask_11_6_1_output_accuracy: 0.0933 - val_block_perm_11_output_accuracy: 0.6564 - val_loss: 39.4590 - val_mask_11_0_0_output_accuracy: 0.0882 - val_mask_11_0_1_output_accuracy: 0.0915 - val_mask_11_1_0_output_accuracy: 0.0867 - val_mask_11_1_1_output_accuracy: 0.0915 - val_mask_11_2_0_output_accuracy: 0.0871 - val_mask_11_2_1_output_accuracy: 0.0934 - val_mask_11_3_0_output_accuracy: 0.0903 - val_mask_11_3_1_output_accuracy: 0.0933 - val_mask_11_4_0_output_accuracy: 0.0883 - val_mask_11_4_1_output_accuracy: 0.0857 - val_mask_11_5_0_output_accuracy: 0.0887 - val_mask_11_5_1_output_accuracy: 0.0919 - val_mask_11_6_0_output_accuracy: 0.0892 - val_mask_11_6_1_output_accuracy: 0.0884
# Epoch 3/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 659s 62ms/step - block_perm_11_output_accuracy: 0.7121 - loss: 39.1157 - mask_11_0_0_output_accuracy: 0.0938 - mask_11_0_1_output_accuracy: 0.0993 - mask_11_1_0_output_accuracy: 0.0905 - mask_11_1_1_output_accuracy: 0.0953 - mask_11_2_0_output_accuracy: 0.0903 - mask_11_2_1_output_accuracy: 0.0955 - mask_11_3_0_output_accuracy: 0.0918 - mask_11_3_1_output_accuracy: 0.0961 - mask_11_4_0_output_accuracy: 0.0909 - mask_11_4_1_output_accuracy: 0.0958 - mask_11_5_0_output_accuracy: 0.0911 - mask_11_5_1_output_accuracy: 0.0965 - mask_11_6_0_output_accuracy: 0.0921 - mask_11_6_1_output_accuracy: 0.0931 - val_block_perm_11_output_accuracy: 0.5829 - val_loss: 40.1695 - val_mask_11_0_0_output_accuracy: 0.0763 - val_mask_11_0_1_output_accuracy: 0.0836 - val_mask_11_1_0_output_accuracy: 0.0846 - val_mask_11_1_1_output_accuracy: 0.0865 - val_mask_11_2_0_output_accuracy: 0.0889 - val_mask_11_2_1_output_accuracy: 0.0951 - val_mask_11_3_0_output_accuracy: 0.0701 - val_mask_11_3_1_output_accuracy: 0.0742 - val_mask_11_4_0_output_accuracy: 0.0805 - val_mask_11_4_1_output_accuracy: 0.0799 - val_mask_11_5_0_output_accuracy: 0.0767 - val_mask_11_5_1_output_accuracy: 0.0839 - val_mask_11_6_0_output_accuracy: 0.0721 - val_mask_11_6_1_output_accuracy: 0.0687
# Epoch 4/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 659s 62ms/step - block_perm_11_output_accuracy: 0.7124 - loss: 39.1095 - mask_11_0_0_output_accuracy: 0.0944 - mask_11_0_1_output_accuracy: 0.0985 - mask_11_1_0_output_accuracy: 0.0902 - mask_11_1_1_output_accuracy: 0.0956 - mask_11_2_0_output_accuracy: 0.0910 - mask_11_2_1_output_accuracy: 0.0959 - mask_11_3_0_output_accuracy: 0.0912 - mask_11_3_1_output_accuracy: 0.0964 - mask_11_4_0_output_accuracy: 0.0917 - mask_11_4_1_output_accuracy: 0.0954 - mask_11_5_0_output_accuracy: 0.0915 - mask_11_5_1_output_accuracy: 0.0953 - mask_11_6_0_output_accuracy: 0.0921 - mask_11_6_1_output_accuracy: 0.0939 - val_block_perm_11_output_accuracy: 0.5445 - val_loss: 40.0355 - val_mask_11_0_0_output_accuracy: 0.0891 - val_mask_11_0_1_output_accuracy: 0.0915 - val_mask_11_1_0_output_accuracy: 0.0808 - val_mask_11_1_1_output_accuracy: 0.0891 - val_mask_11_2_0_output_accuracy: 0.0893 - val_mask_11_2_1_output_accuracy: 0.0941 - val_mask_11_3_0_output_accuracy: 0.0910 - val_mask_11_3_1_output_accuracy: 0.0929 - val_mask_11_4_0_output_accuracy: 0.0883 - val_mask_11_4_1_output_accuracy: 0.0877 - val_mask_11_5_0_output_accuracy: 0.0755 - val_mask_11_5_1_output_accuracy: 0.0825 - val_mask_11_6_0_output_accuracy: 0.0785 - val_mask_11_6_1_output_accuracy: 0.0705
# Epoch 5/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 660s 63ms/step - block_perm_11_output_accuracy: 0.7121 - loss: 39.1022 - mask_11_0_0_output_accuracy: 0.0940 - mask_11_0_1_output_accuracy: 0.0997 - mask_11_1_0_output_accuracy: 0.0904 - mask_11_1_1_output_accuracy: 0.0968 - mask_11_2_0_output_accuracy: 0.0906 - mask_11_2_1_output_accuracy: 0.0956 - mask_11_3_0_output_accuracy: 0.0910 - mask_11_3_1_output_accuracy: 0.0962 - mask_11_4_0_output_accuracy: 0.0923 - mask_11_4_1_output_accuracy: 0.0957 - mask_11_5_0_output_accuracy: 0.0915 - mask_11_5_1_output_accuracy: 0.0976 - mask_11_6_0_output_accuracy: 0.0925 - mask_11_6_1_output_accuracy: 0.0941 - val_block_perm_11_output_accuracy: 0.6188 - val_loss: 39.6918 - val_mask_11_0_0_output_accuracy: 0.0907 - val_mask_11_0_1_output_accuracy: 0.0918 - val_mask_11_1_0_output_accuracy: 0.0816 - val_mask_11_1_1_output_accuracy: 0.0817 - val_mask_11_2_0_output_accuracy: 0.0825 - val_mask_11_2_1_output_accuracy: 0.0895 - val_mask_11_3_0_output_accuracy: 0.0905 - val_mask_11_3_1_output_accuracy: 0.0927 - val_mask_11_4_0_output_accuracy: 0.0903 - val_mask_11_4_1_output_accuracy: 0.0919 - val_mask_11_5_0_output_accuracy: 0.0846 - val_mask_11_5_1_output_accuracy: 0.0906 - val_mask_11_6_0_output_accuracy: 0.0797 - val_mask_11_6_1_output_accuracy: 0.0717
# Epoch 6/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 660s 63ms/step - block_perm_11_output_accuracy: 0.7136 - loss: 39.0972 - mask_11_0_0_output_accuracy: 0.0940 - mask_11_0_1_output_accuracy: 0.0993 - mask_11_1_0_output_accuracy: 0.0895 - mask_11_1_1_output_accuracy: 0.0962 - mask_11_2_0_output_accuracy: 0.0910 - mask_11_2_1_output_accuracy: 0.0965 - mask_11_3_0_output_accuracy: 0.0915 - mask_11_3_1_output_accuracy: 0.0963 - mask_11_4_0_output_accuracy: 0.0918 - mask_11_4_1_output_accuracy: 0.0954 - mask_11_5_0_output_accuracy: 0.0909 - mask_11_5_1_output_accuracy: 0.0965 - mask_11_6_0_output_accuracy: 0.0921 - mask_11_6_1_output_accuracy: 0.0940 - val_block_perm_11_output_accuracy: 0.4909 - val_loss: 41.3040 - val_mask_11_0_0_output_accuracy: 0.0690 - val_mask_11_0_1_output_accuracy: 0.0878 - val_mask_11_1_0_output_accuracy: 0.0729 - val_mask_11_1_1_output_accuracy: 0.0837 - val_mask_11_2_0_output_accuracy: 0.0695 - val_mask_11_2_1_output_accuracy: 0.0763 - val_mask_11_3_0_output_accuracy: 0.0715 - val_mask_11_3_1_output_accuracy: 0.0762 - val_mask_11_4_0_output_accuracy: 0.0664 - val_mask_11_4_1_output_accuracy: 0.0649 - val_mask_11_5_0_output_accuracy: 0.0719 - val_mask_11_5_1_output_accuracy: 0.0755 - val_mask_11_6_0_output_accuracy: 0.0846 - val_mask_11_6_1_output_accuracy: 0.0853
# Epoch 7/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 662s 63ms/step - block_perm_11_output_accuracy: 0.7138 - loss: 39.0922 - mask_11_0_0_output_accuracy: 0.0932 - mask_11_0_1_output_accuracy: 0.0990 - mask_11_1_0_output_accuracy: 0.0902 - mask_11_1_1_output_accuracy: 0.0965 - mask_11_2_0_output_accuracy: 0.0901 - mask_11_2_1_output_accuracy: 0.0964 - mask_11_3_0_output_accuracy: 0.0918 - mask_11_3_1_output_accuracy: 0.0963 - mask_11_4_0_output_accuracy: 0.0916 - mask_11_4_1_output_accuracy: 0.0953 - mask_11_5_0_output_accuracy: 0.0916 - mask_11_5_1_output_accuracy: 0.0967 - mask_11_6_0_output_accuracy: 0.0918 - mask_11_6_1_output_accuracy: 0.0928 - val_block_perm_11_output_accuracy: 0.6223 - val_loss: 39.9365 - val_mask_11_0_0_output_accuracy: 0.0708 - val_mask_11_0_1_output_accuracy: 0.0745 - val_mask_11_1_0_output_accuracy: 0.0886 - val_mask_11_1_1_output_accuracy: 0.0904 - val_mask_11_2_0_output_accuracy: 0.0886 - val_mask_11_2_1_output_accuracy: 0.0940 - val_mask_11_3_0_output_accuracy: 0.0899 - val_mask_11_3_1_output_accuracy: 0.0901 - val_mask_11_4_0_output_accuracy: 0.0806 - val_mask_11_4_1_output_accuracy: 0.0896 - val_mask_11_5_0_output_accuracy: 0.0656 - val_mask_11_5_1_output_accuracy: 0.0712 - val_mask_11_6_0_output_accuracy: 0.0870 - val_mask_11_6_1_output_accuracy: 0.0896
# Epoch 8/1000
#  5434/10547 ━━━━━━━━━━━━━━━━━━━━ 5:14 62ms/step - block_perm_11_output_accuracy: 0.7141 - loss: 39.0859 - mask_11_0_0_output_accuracy: 0.0936 - mask_11_0_1_output_accuracy: 0.1010 - mask_11_1_0_output_accuracy: 0.0894 - mask_11_1_1_output_accuracy: 0.0973 - mask_11_2_0_output_accuracy: 0.0910 - mask_11_2_1_output_accuracy: 0.0962 - mask_11_3_0_output_accuracy: 0.0927 - mask_11_3_1_output_accuracy: 0.0972 - mask_11_4_0_output_accuracy: 0.0917 - mask_11_4_1_output_accuracy: 0.0961 - mask_11_5_0_output_accuracy: 0.0919 - mask_11_5_1_output_accuracy: 0.0961 - mask_11_6_0_output_accuracy: 0.0928 - mask_11_6_1_output_accuracy: 0.0935
