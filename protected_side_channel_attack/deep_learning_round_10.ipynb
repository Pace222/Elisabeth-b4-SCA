# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "4"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning
# Out:
# 2024-06-12 12:07:15.520105: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-12 12:07:15.574552: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 12:07:16.535337: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
if True:
    with open("splitted_round_10.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_round_10_adjusted_only.pic", "rb") as r:
        traces_round_10 = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_round_10, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_round_10.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_round_10", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_round_10_adjusted.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_round_10_adjusted.keras")
except ValueError:
    pass
# Out:
# 2024-06-12 12:07:22.302608: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.357980: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.358037: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.374034: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.374099: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.374130: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.586604: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.586666: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.586676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-12 12:07:22.586713: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b1:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:22.586740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9057 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_round_10_adjusted.keras", patience=10)
# Out:
# Epoch 1/1000
# 2024-06-12 12:07:57.661759: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# /root/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718186877.891841    5143 service.cc:145] XLA service 0x7fee54076510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1718186877.891894    5143 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-06-12 12:07:58.670255: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-12 12:08:01.252319: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-06-12 12:08:05.032186: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 12.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718186895.870953    5143 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_40', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1718186895.908138    5143 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  2095/10547 ━━━━━━━━━━━━━━━━━━━━ 8:21 59ms/step - block_perm_10_output_accuracy: 0.7102 - loss: 39.1779 - mask_10_0_0_output_accuracy: 0.0933 - mask_10_0_1_output_accuracy: 0.0984 - mask_10_1_0_output_accuracy: 0.0896 - mask_10_1_1_output_accuracy: 0.0943 - mask_10_2_0_output_accuracy: 0.0886 - mask_10_2_1_output_accuracy: 0.0938 - mask_10_3_0_output_accuracy: 0.0895 - mask_10_3_1_output_accuracy: 0.0930 - mask_10_4_0_output_accuracy: 0.0931 - mask_10_4_1_output_accuracy: 0.0937 - mask_10_5_0_output_accuracy: 0.0902 - mask_10_5_1_output_accuracy: 0.0943 - mask_10_6_0_output_accuracy: 0.0907 - mask_10_6_1_output_accuracy: 0.0921
# 2024-06-12 12:10:26.441602: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 11.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1718187038.465013    5146 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 120 bytes spill stores, 120 bytes spill loads
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 709s 64ms/step - block_perm_10_output_accuracy: 0.7101 - loss: 39.1807 - mask_10_0_0_output_accuracy: 0.0931 - mask_10_0_1_output_accuracy: 0.0984 - mask_10_1_0_output_accuracy: 0.0899 - mask_10_1_1_output_accuracy: 0.0943 - mask_10_2_0_output_accuracy: 0.0891 - mask_10_2_1_output_accuracy: 0.0943 - mask_10_3_0_output_accuracy: 0.0902 - mask_10_3_1_output_accuracy: 0.0945 - mask_10_4_0_output_accuracy: 0.0926 - mask_10_4_1_output_accuracy: 0.0939 - mask_10_5_0_output_accuracy: 0.0908 - mask_10_5_1_output_accuracy: 0.0953 - mask_10_6_0_output_accuracy: 0.0912 - mask_10_6_1_output_accuracy: 0.0926 - val_block_perm_10_output_accuracy: 0.6068 - val_loss: 39.8265 - val_mask_10_0_0_output_accuracy: 0.0823 - val_mask_10_0_1_output_accuracy: 0.0954 - val_mask_10_1_0_output_accuracy: 0.0718 - val_mask_10_1_1_output_accuracy: 0.0865 - val_mask_10_2_0_output_accuracy: 0.0796 - val_mask_10_2_1_output_accuracy: 0.0844 - val_mask_10_3_0_output_accuracy: 0.0887 - val_mask_10_3_1_output_accuracy: 0.0877 - val_mask_10_4_0_output_accuracy: 0.0856 - val_mask_10_4_1_output_accuracy: 0.0905 - val_mask_10_5_0_output_accuracy: 0.0738 - val_mask_10_5_1_output_accuracy: 0.0860 - val_mask_10_6_0_output_accuracy: 0.0757 - val_mask_10_6_1_output_accuracy: 0.0793
# Epoch 2/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 653s 62ms/step - block_perm_10_output_accuracy: 0.7106 - loss: 39.1693 - mask_10_0_0_output_accuracy: 0.0940 - mask_10_0_1_output_accuracy: 0.0981 - mask_10_1_0_output_accuracy: 0.0900 - mask_10_1_1_output_accuracy: 0.0948 - mask_10_2_0_output_accuracy: 0.0906 - mask_10_2_1_output_accuracy: 0.0940 - mask_10_3_0_output_accuracy: 0.0907 - mask_10_3_1_output_accuracy: 0.0942 - mask_10_4_0_output_accuracy: 0.0927 - mask_10_4_1_output_accuracy: 0.0939 - mask_10_5_0_output_accuracy: 0.0909 - mask_10_5_1_output_accuracy: 0.0956 - mask_10_6_0_output_accuracy: 0.0916 - mask_10_6_1_output_accuracy: 0.0932 - val_block_perm_10_output_accuracy: 0.6875 - val_loss: 39.4199 - val_mask_10_0_0_output_accuracy: 0.0879 - val_mask_10_0_1_output_accuracy: 0.0921 - val_mask_10_1_0_output_accuracy: 0.0879 - val_mask_10_1_1_output_accuracy: 0.0924 - val_mask_10_2_0_output_accuracy: 0.0875 - val_mask_10_2_1_output_accuracy: 0.0909 - val_mask_10_3_0_output_accuracy: 0.0878 - val_mask_10_3_1_output_accuracy: 0.0936 - val_mask_10_4_0_output_accuracy: 0.0872 - val_mask_10_4_1_output_accuracy: 0.0788 - val_mask_10_5_0_output_accuracy: 0.0837 - val_mask_10_5_1_output_accuracy: 0.0940 - val_mask_10_6_0_output_accuracy: 0.0868 - val_mask_10_6_1_output_accuracy: 0.0851
# Epoch 3/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 651s 62ms/step - block_perm_10_output_accuracy: 0.7101 - loss: 39.1632 - mask_10_0_0_output_accuracy: 0.0941 - mask_10_0_1_output_accuracy: 0.0986 - mask_10_1_0_output_accuracy: 0.0909 - mask_10_1_1_output_accuracy: 0.0951 - mask_10_2_0_output_accuracy: 0.0903 - mask_10_2_1_output_accuracy: 0.0945 - mask_10_3_0_output_accuracy: 0.0908 - mask_10_3_1_output_accuracy: 0.0958 - mask_10_4_0_output_accuracy: 0.0921 - mask_10_4_1_output_accuracy: 0.0937 - mask_10_5_0_output_accuracy: 0.0910 - mask_10_5_1_output_accuracy: 0.0959 - mask_10_6_0_output_accuracy: 0.0914 - mask_10_6_1_output_accuracy: 0.0931 - val_block_perm_10_output_accuracy: 0.6691 - val_loss: 39.4665 - val_mask_10_0_0_output_accuracy: 0.0930 - val_mask_10_0_1_output_accuracy: 0.0968 - val_mask_10_1_0_output_accuracy: 0.0880 - val_mask_10_1_1_output_accuracy: 0.0916 - val_mask_10_2_0_output_accuracy: 0.0807 - val_mask_10_2_1_output_accuracy: 0.0809 - val_mask_10_3_0_output_accuracy: 0.0901 - val_mask_10_3_1_output_accuracy: 0.0889 - val_mask_10_4_0_output_accuracy: 0.0853 - val_mask_10_4_1_output_accuracy: 0.0866 - val_mask_10_5_0_output_accuracy: 0.0858 - val_mask_10_5_1_output_accuracy: 0.0896 - val_mask_10_6_0_output_accuracy: 0.0907 - val_mask_10_6_1_output_accuracy: 0.0915
# Epoch 4/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 651s 62ms/step - block_perm_10_output_accuracy: 0.7111 - loss: 39.1554 - mask_10_0_0_output_accuracy: 0.0932 - mask_10_0_1_output_accuracy: 0.0975 - mask_10_1_0_output_accuracy: 0.0904 - mask_10_1_1_output_accuracy: 0.0955 - mask_10_2_0_output_accuracy: 0.0898 - mask_10_2_1_output_accuracy: 0.0944 - mask_10_3_0_output_accuracy: 0.0921 - mask_10_3_1_output_accuracy: 0.0955 - mask_10_4_0_output_accuracy: 0.0922 - mask_10_4_1_output_accuracy: 0.0954 - mask_10_5_0_output_accuracy: 0.0906 - mask_10_5_1_output_accuracy: 0.0961 - mask_10_6_0_output_accuracy: 0.0917 - mask_10_6_1_output_accuracy: 0.0932 - val_block_perm_10_output_accuracy: 0.6048 - val_loss: 40.1685 - val_mask_10_0_0_output_accuracy: 0.0907 - val_mask_10_0_1_output_accuracy: 0.0911 - val_mask_10_1_0_output_accuracy: 0.0676 - val_mask_10_1_1_output_accuracy: 0.0679 - val_mask_10_2_0_output_accuracy: 0.0790 - val_mask_10_2_1_output_accuracy: 0.0863 - val_mask_10_3_0_output_accuracy: 0.0879 - val_mask_10_3_1_output_accuracy: 0.0838 - val_mask_10_4_0_output_accuracy: 0.0914 - val_mask_10_4_1_output_accuracy: 0.0847 - val_mask_10_5_0_output_accuracy: 0.0877 - val_mask_10_5_1_output_accuracy: 0.0898 - val_mask_10_6_0_output_accuracy: 0.0728 - val_mask_10_6_1_output_accuracy: 0.0725
# Epoch 5/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 651s 62ms/step - block_perm_10_output_accuracy: 0.7108 - loss: 39.1499 - mask_10_0_0_output_accuracy: 0.0937 - mask_10_0_1_output_accuracy: 0.0991 - mask_10_1_0_output_accuracy: 0.0897 - mask_10_1_1_output_accuracy: 0.0954 - mask_10_2_0_output_accuracy: 0.0906 - mask_10_2_1_output_accuracy: 0.0950 - mask_10_3_0_output_accuracy: 0.0906 - mask_10_3_1_output_accuracy: 0.0958 - mask_10_4_0_output_accuracy: 0.0919 - mask_10_4_1_output_accuracy: 0.0947 - mask_10_5_0_output_accuracy: 0.0915 - mask_10_5_1_output_accuracy: 0.0966 - mask_10_6_0_output_accuracy: 0.0913 - mask_10_6_1_output_accuracy: 0.0936 - val_block_perm_10_output_accuracy: 0.6505 - val_loss: 39.7183 - val_mask_10_0_0_output_accuracy: 0.0843 - val_mask_10_0_1_output_accuracy: 0.0953 - val_mask_10_1_0_output_accuracy: 0.0809 - val_mask_10_1_1_output_accuracy: 0.0762 - val_mask_10_2_0_output_accuracy: 0.0863 - val_mask_10_2_1_output_accuracy: 0.0856 - val_mask_10_3_0_output_accuracy: 0.0869 - val_mask_10_3_1_output_accuracy: 0.0872 - val_mask_10_4_0_output_accuracy: 0.0808 - val_mask_10_4_1_output_accuracy: 0.0865 - val_mask_10_5_0_output_accuracy: 0.0886 - val_mask_10_5_1_output_accuracy: 0.0944 - val_mask_10_6_0_output_accuracy: 0.0706 - val_mask_10_6_1_output_accuracy: 0.0818
# Epoch 6/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 654s 62ms/step - block_perm_10_output_accuracy: 0.7113 - loss: 39.1449 - mask_10_0_0_output_accuracy: 0.0936 - mask_10_0_1_output_accuracy: 0.0987 - mask_10_1_0_output_accuracy: 0.0904 - mask_10_1_1_output_accuracy: 0.0954 - mask_10_2_0_output_accuracy: 0.0909 - mask_10_2_1_output_accuracy: 0.0958 - mask_10_3_0_output_accuracy: 0.0909 - mask_10_3_1_output_accuracy: 0.0953 - mask_10_4_0_output_accuracy: 0.0923 - mask_10_4_1_output_accuracy: 0.0949 - mask_10_5_0_output_accuracy: 0.0907 - mask_10_5_1_output_accuracy: 0.0961 - mask_10_6_0_output_accuracy: 0.0916 - mask_10_6_1_output_accuracy: 0.0930 - val_block_perm_10_output_accuracy: 0.5679 - val_loss: 39.8337 - val_mask_10_0_0_output_accuracy: 0.0802 - val_mask_10_0_1_output_accuracy: 0.0871 - val_mask_10_1_0_output_accuracy: 0.0861 - val_mask_10_1_1_output_accuracy: 0.0870 - val_mask_10_2_0_output_accuracy: 0.0903 - val_mask_10_2_1_output_accuracy: 0.0933 - val_mask_10_3_0_output_accuracy: 0.0824 - val_mask_10_3_1_output_accuracy: 0.0902 - val_mask_10_4_0_output_accuracy: 0.0874 - val_mask_10_4_1_output_accuracy: 0.0855 - val_mask_10_5_0_output_accuracy: 0.0767 - val_mask_10_5_1_output_accuracy: 0.0797 - val_mask_10_6_0_output_accuracy: 0.0904 - val_mask_10_6_1_output_accuracy: 0.0906
# Epoch 7/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 655s 62ms/step - block_perm_10_output_accuracy: 0.7122 - loss: 39.1378 - mask_10_0_0_output_accuracy: 0.0941 - mask_10_0_1_output_accuracy: 0.0981 - mask_10_1_0_output_accuracy: 0.0906 - mask_10_1_1_output_accuracy: 0.0953 - mask_10_2_0_output_accuracy: 0.0906 - mask_10_2_1_output_accuracy: 0.0947 - mask_10_3_0_output_accuracy: 0.0905 - mask_10_3_1_output_accuracy: 0.0954 - mask_10_4_0_output_accuracy: 0.0929 - mask_10_4_1_output_accuracy: 0.0950 - mask_10_5_0_output_accuracy: 0.0910 - mask_10_5_1_output_accuracy: 0.0967 - mask_10_6_0_output_accuracy: 0.0923 - mask_10_6_1_output_accuracy: 0.0934 - val_block_perm_10_output_accuracy: 0.5465 - val_loss: 40.0218 - val_mask_10_0_0_output_accuracy: 0.0863 - val_mask_10_0_1_output_accuracy: 0.0965 - val_mask_10_1_0_output_accuracy: 0.0785 - val_mask_10_1_1_output_accuracy: 0.0858 - val_mask_10_2_0_output_accuracy: 0.0795 - val_mask_10_2_1_output_accuracy: 0.0848 - val_mask_10_3_0_output_accuracy: 0.0903 - val_mask_10_3_1_output_accuracy: 0.0937 - val_mask_10_4_0_output_accuracy: 0.0818 - val_mask_10_4_1_output_accuracy: 0.0932 - val_mask_10_5_0_output_accuracy: 0.0874 - val_mask_10_5_1_output_accuracy: 0.0931 - val_mask_10_6_0_output_accuracy: 0.0865 - val_mask_10_6_1_output_accuracy: 0.0918
# Epoch 8/1000
#  9614/10547 ━━━━━━━━━━━━━━━━━━━━ 56s 61ms/step - block_perm_10_output_accuracy: 0.7128 - loss: 39.1252 - mask_10_0_0_output_accuracy: 0.0939 - mask_10_0_1_output_accuracy: 0.0999 - mask_10_1_0_output_accuracy: 0.0902 - mask_10_1_1_output_accuracy: 0.0956 - mask_10_2_0_output_accuracy: 0.0901 - mask_10_2_1_output_accuracy: 0.0947 - mask_10_3_0_output_accuracy: 0.0916 - mask_10_3_1_output_accuracy: 0.0956 - mask_10_4_0_output_accuracy: 0.0920 - mask_10_4_1_output_accuracy: 0.0955 - mask_10_5_0_output_accuracy: 0.0914 - mask_10_5_1_output_accuracy: 0.0972 - mask_10_6_0_output_accuracy: 0.0919 - mask_10_6_1_output_accuracy: 0.0940
