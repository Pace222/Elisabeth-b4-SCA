# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "6"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning

# %%
if True:
    with open("splitted_rws.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_rws_only.pic", "rb") as r:
        traces_rws_only = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_rws_only, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_rws.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_rws_only", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_rws.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_rws.keras")
except ValueError:
    pass

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_rws.keras", patience=10)
# Out:
# Epoch 1/1000
# 5274/5274 [==============================] - 6764s 1s/step - loss: 548.0638 - rws_perm_output_loss: 4.5858 - rws_mask_0_0_output_loss: 2.7729 - rws_mask_0_1_output_loss: 2.7729 - rws_mask_1_0_output_loss: 2.7729 - rws_mask_1_1_output_loss: 2.7729 - rws_mask_2_0_output_loss: 2.7729 - rws_mask_2_1_output_loss: 2.7729 - rws_mask_3_0_output_loss: 2.7729 - rws_mask_3_1_output_loss: 2.7729 - rws_mask_4_0_output_loss: 2.7729 - rws_mask_4_1_output_loss: 2.7729 - rws_mask_5_0_output_loss: 2.7729 - rws_mask_5_1_output_loss: 2.7729 - rws_mask_6_0_output_loss: 2.7729 - rws_mask_6_1_output_loss: 2.7729 - rws_mask_7_0_output_loss: 2.7729 - rws_mask_7_1_output_loss: 2.7729 - rws_mask_8_0_output_loss: 2.7729 - rws_mask_8_1_output_loss: 2.7729 - rws_mask_9_0_output_loss: 2.7729 - rws_mask_9_1_output_loss: 2.7729 - rws_mask_10_0_output_loss: 2.7729 - rws_mask_10_1_output_loss: 2.7729 - rws_mask_11_0_output_loss: 2.7729 - rws_mask_11_1_output_loss: 2.7729 - rws_mask_12_0_output_loss: 2.7729 - rws_mask_12_1_output_loss: 2.7729 - rws_mask_13_0_output_loss: 2.7729 - rws_mask_13_1_output_loss: 2.7729 - rws_mask_14_0_output_loss: 2.7729 - rws_mask_14_1_output_loss: 2.7729 - rws_mask_15_0_output_loss: 2.7729 - rws_mask_15_1_output_loss: 2.7729 - rws_mask_16_0_output_loss: 2.7729 - rws_mask_16_1_output_loss: 2.7729 - rws_mask_17_0_output_loss: 2.7729 - rws_mask_17_1_output_loss: 2.7729 - rws_mask_18_0_output_loss: 2.7729 - rws_mask_18_1_output_loss: 2.7729 - rws_mask_19_0_output_loss: 2.7729 - rws_mask_19_1_output_loss: 2.7729 - rws_mask_20_0_output_loss: 2.7729 - rws_mask_20_1_output_loss: 2.7729 - rws_mask_21_0_output_loss: 2.7729 - rws_mask_21_1_output_loss: 2.7729 - rws_mask_22_0_output_loss: 2.7729 - rws_mask_22_1_output_loss: 2.7729 - rws_mask_23_0_output_loss: 2.7729 - rws_mask_23_1_output_loss: 2.7729 - rws_mask_24_0_output_loss: 2.7729 - rws_mask_24_1_output_loss: 2.7729 - rws_mask_25_0_output_loss: 2.7729 - rws_mask_25_1_output_loss: 2.7729 - rws_mask_26_0_output_loss: 2.7729 - rws_mask_26_1_output_loss: 2.7729 - rws_mask_27_0_output_loss: 2.7729 - rws_mask_27_1_output_loss: 2.7729 - rws_mask_28_0_output_loss: 2.7729 - rws_mask_28_1_output_loss: 2.7729 - rws_mask_29_0_output_loss: 2.7729 - rws_mask_29_1_output_loss: 2.7729 - rws_mask_30_0_output_loss: 2.7729 - rws_mask_30_1_output_loss: 2.7729 - rws_mask_31_0_output_loss: 2.7729 - rws_mask_31_1_output_loss: 2.7729 - rws_mask_32_0_output_loss: 2.7729 - rws_mask_32_1_output_loss: 2.7729 - rws_mask_33_0_output_loss: 2.7729 - rws_mask_33_1_output_loss: 2.7729 - rws_mask_34_0_output_loss: 2.7729 - rws_mask_34_1_output_loss: 2.7729 - rws_mask_35_0_output_loss: 2.7729 - rws_mask_35_1_output_loss: 2.7729 - rws_mask_36_0_output_loss: 2.7729 - rws_mask_36_1_output_loss: 2.7729 - rws_mask_37_0_output_loss: 2.7729 - rws_mask_37_1_output_loss: 2.7729 - rws_mask_38_0_output_loss: 2.7729 - rws_mask_38_1_output_loss: 2.7729 - rws_mask_39_0_output_loss: 2.7729 - rws_mask_39_1_output_loss: 2.7729 - rws_mask_40_0_output_loss: 2.7729 - rws_mask_40_1_output_loss: 2.7729 - rws_mask_41_0_output_loss: 2.7729 - rws_mask_41_1_output_loss: 2.7729 - rws_mask_42_0_output_loss: 2.7729 - rws_mask_42_1_output_loss: 2.7729 - rws_mask_43_0_output_loss: 2.7729 - rws_mask_43_1_output_loss: 2.7729 - rws_mask_44_0_output_loss: 2.7729 - rws_mask_44_1_output_loss: 2.7729 - rws_mask_45_0_output_loss: 2.7729 - rws_mask_45_1_output_loss: 2.7729 - rws_mask_46_0_output_loss: 2.7730 - rws_mask_46_1_output_loss: 2.7729 - rws_mask_47_0_output_loss: 2.7729 - rws_mask_47_1_output_loss: 2.7729 - rws_mask_48_0_output_loss: 2.7729 - rws_mask_48_1_output_loss: 2.7729 - rws_mask_49_0_output_loss: 2.7729 - rws_mask_49_1_output_loss: 2.7729 - rws_mask_50_0_output_loss: 2.7729 - rws_mask_50_1_output_loss: 2.7729 - rws_mask_51_0_output_loss: 2.7729 - rws_mask_51_1_output_loss: 2.7729 - rws_mask_52_0_output_loss: 2.7729 - rws_mask_52_1_output_loss: 2.7729 - rws_mask_53_0_output_loss: 2.7729 - rws_mask_53_1_output_loss: 2.7730 - rws_mask_54_0_output_lo ...
# Epoch 2/1000
# 2569/5274 [=============>................] - ETA: 54:18 - loss: 548.0629 - rws_perm_output_loss: 4.5858 - rws_mask_0_0_output_loss: 2.7728 - rws_mask_0_1_output_loss: 2.7729 - rws_mask_1_0_output_loss: 2.7728 - rws_mask_1_1_output_loss: 2.7728 - rws_mask_2_0_output_loss: 2.7728 - rws_mask_2_1_output_loss: 2.7729 - rws_mask_3_0_output_loss: 2.7728 - rws_mask_3_1_output_loss: 2.7728 - rws_mask_4_0_output_loss: 2.7729 - rws_mask_4_1_output_loss: 2.7729 - rws_mask_5_0_output_loss: 2.7729 - rws_mask_5_1_output_loss: 2.7729 - rws_mask_6_0_output_loss: 2.7729 - rws_mask_6_1_output_loss: 2.7728 - rws_mask_7_0_output_loss: 2.7728 - rws_mask_7_1_output_loss: 2.7728 - rws_mask_8_0_output_loss: 2.7728 - rws_mask_8_1_output_loss: 2.7729 - rws_mask_9_0_output_loss: 2.7729 - rws_mask_9_1_output_loss: 2.7728 - rws_mask_10_0_output_loss: 2.7728 - rws_mask_10_1_output_loss: 2.7729 - rws_mask_11_0_output_loss: 2.7728 - rws_mask_11_1_output_loss: 2.7729 - rws_mask_12_0_output_loss: 2.7728 - rws_mask_12_1_output_loss: 2.7728 - rws_mask_13_0_output_loss: 2.7729 - rws_mask_13_1_output_loss: 2.7728 - rws_mask_14_0_output_loss: 2.7728 - rws_mask_14_1_output_loss: 2.7729 - rws_mask_15_0_output_loss: 2.7728 - rws_mask_15_1_output_loss: 2.7728 - rws_mask_16_0_output_loss: 2.7728 - rws_mask_16_1_output_loss: 2.7729 - rws_mask_17_0_output_loss: 2.7729 - rws_mask_17_1_output_loss: 2.7728 - rws_mask_18_0_output_loss: 2.7728 - rws_mask_18_1_output_loss: 2.7729 - rws_mask_19_0_output_loss: 2.7729 - rws_mask_19_1_output_loss: 2.7728 - rws_mask_20_0_output_loss: 2.7728 - rws_mask_20_1_output_loss: 2.7728 - rws_mask_21_0_output_loss: 2.7729 - rws_mask_21_1_output_loss: 2.7729 - rws_mask_22_0_output_loss: 2.7728 - rws_mask_22_1_output_loss: 2.7729 - rws_mask_23_0_output_loss: 2.7728 - rws_mask_23_1_output_loss: 2.7729 - rws_mask_24_0_output_loss: 2.7729 - rws_mask_24_1_output_loss: 2.7729 - rws_mask_25_0_output_loss: 2.7728 - rws_mask_25_1_output_loss: 2.7728 - rws_mask_26_0_output_loss: 2.7728 - rws_mask_26_1_output_loss: 2.7729 - rws_mask_27_0_output_loss: 2.7729 - rws_mask_27_1_output_loss: 2.7728 - rws_mask_28_0_output_loss: 2.7728 - rws_mask_28_1_output_loss: 2.7729 - rws_mask_29_0_output_loss: 2.7729 - rws_mask_29_1_output_loss: 2.7728 - rws_mask_30_0_output_loss: 2.7728 - rws_mask_30_1_output_loss: 2.7729 - rws_mask_31_0_output_loss: 2.7728 - rws_mask_31_1_output_loss: 2.7729 - rws_mask_32_0_output_loss: 2.7728 - rws_mask_32_1_output_loss: 2.7728 - rws_mask_33_0_output_loss: 2.7729 - rws_mask_33_1_output_loss: 2.7728 - rws_mask_34_0_output_loss: 2.7729 - rws_mask_34_1_output_loss: 2.7729 - rws_mask_35_0_output_loss: 2.7729 - rws_mask_35_1_output_loss: 2.7729 - rws_mask_36_0_output_loss: 2.7729 - rws_mask_36_1_output_loss: 2.7728 - rws_mask_37_0_output_loss: 2.7728 - rws_mask_37_1_output_loss: 2.7728 - rws_mask_38_0_output_loss: 2.7729 - rws_mask_38_1_output_loss: 2.7728 - rws_mask_39_0_output_loss: 2.7729 - rws_mask_39_1_output_loss: 2.7729 - rws_mask_40_0_output_loss: 2.7729 - rws_mask_40_1_output_loss: 2.7728 - rws_mask_41_0_output_loss: 2.7729 - rws_mask_41_1_output_loss: 2.7728 - rws_mask_42_0_output_loss: 2.7729 - rws_mask_42_1_output_loss: 2.7728 - rws_mask_43_0_output_loss: 2.7729 - rws_mask_43_1_output_loss: 2.7729 - rws_mask_44_0_output_loss: 2.7729 - rws_mask_44_1_output_loss: 2.7729 - rws_mask_45_0_output_loss: 2.7729 - rws_mask_45_1_output_loss: 2.7729 - rws_mask_46_0_output_loss: 2.7729 - rws_mask_46_1_output_loss: 2.7728 - rws_mask_47_0_output_loss: 2.7728 - rws_mask_47_1_output_loss: 2.7729 - rws_mask_48_0_output_loss: 2.7729 - rws_mask_48_1_output_loss: 2.7728 - rws_mask_49_0_output_loss: 2.7729 - rws_mask_49_1_output_loss: 2.7728 - rws_mask_50_0_output_loss: 2.7729 - rws_mask_50_1_output_loss: 2.7729 - rws_mask_51_0_output_loss: 2.7728 - rws_mask_51_1_output_loss: 2.7729 - rws_mask_52_0_output_loss: 2.7728 - rws_mask_52_1_output_loss: 2.7728 - rws_mask_53_0_output_loss: 2.7728 - rws_mask_53_1_output_loss: 2.7729 - rws_mask_54_0_output_loss: ...
