# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "1"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning

# %%
if True:
    with open("splitted_round_5.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_round_5_adjusted_only.pic", "rb") as r:
        traces_round_5 = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_round_5, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_round_5.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_round_5", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_round_5_adjusted.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_round_5_adjusted.keras")
except ValueError:
    pass

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_round_5_adjusted.keras", patience=10)
# Out:
# Epoch 1/1000
# 10547/10547 [==============================] - 1908s 180ms/step - loss: 41.2732 - block_perm_5_output_loss: 1.9913 - mask_5_0_0_output_loss: 2.8063 - mask_5_0_1_output_loss: 2.8070 - mask_5_1_0_output_loss: 2.8033 - mask_5_1_1_output_loss: 2.8041 - mask_5_2_0_output_loss: 2.8057 - mask_5_2_1_output_loss: 2.8068 - mask_5_3_0_output_loss: 2.8061 - mask_5_3_1_output_loss: 2.8038 - mask_5_4_0_output_loss: 2.8074 - mask_5_4_1_output_loss: 2.8061 - mask_5_5_0_output_loss: 2.8072 - mask_5_5_1_output_loss: 2.8053 - mask_5_6_0_output_loss: 2.8076 - mask_5_6_1_output_loss: 2.8049 - block_perm_5_output_accuracy: 0.1440 - mask_5_0_0_output_accuracy: 0.0626 - mask_5_
_output_accuracy: 0.0673 - mask_5_3_1_output_accuracy: 0.0680 - mask_5_4_0_output_accuracy: 0.0661 - mask_5_4_1_output_accuracy: 0.0665 - mask_5_5_0_output_accuracy: 0.0659 - mask_5_5_1_output_accuracy: 0.0661 - mask_5_6_0_output_accuracy: 0.0673 - mask_5_6_1_output_accuracy: 0.0678 - val_loss: 42.3759 - val_block_perm_5_output_loss: 2.2701 - val_mask_5_0_0_output_loss: 2.7626 - val_mask_5_0_1_output_loss: 2.8509 - val_mask_5_1_0_output_loss: 3.0574 - val_mask_5_1_1_output_loss: 2.8664 - val_mask_5_2_0_output_loss: 2.8285 - val_mask_5_2_1_output_loss: 2.7907 - val_mask_5_3_0_output_loss: 2.9635 - val_mask_5_3_1_output_loss: 3.0015 - val_mask_5_4_0_output_loss: 2.8174 - val_mask_5_4_1_output_loss: 2.7812 - val_mask_5_5_0_output_loss: 2.8922 - val_mask_5_5_1_output_loss: 2.8155 - val_mask_5_6_0_output_loss: 2.7745 - val_mask_5_6_1_output_loss: 2.9038 - val_block_perm_5_output_accuracy: 0.3180 - val_mask_5_0_0_output_accuracy: 0.0753 - val_mask_5_0_1_output_accuracy: 0.0646 - val_mask_5_1_0_output_accuracy: 0.0644 - val_mask_5_1_1_output_accuracy: 0.0692 - val_mask_5_2_0_output_accuracy: 0.0686 - val_mask_5_2_1_output_accuracy: 0.0731 - val_mask_5_3_0_output_accuracy: 0.0632 - val_mask_5_3_1_output_accuracy: 0.0664 - val_mask_5_4_0_output_accuracy: 0.0665 - val_mask_5_4_1_output_accuracy: 0.0774 - val_mask_5_5_0_output_accuracy: 0.0637 - val_mask_5_5_1_output_accuracy: 0.0650 - val_mask_5_6_0_output_accuracy: 0.0771 - val_mask_5_6_1_output_accuracy: 0.0655
# Epoch 4/1000
# 10547/10547 [==============================] - 2053s 195ms/step - loss: 39.5926 - block_perm_5_output_loss: 1.1138 - mask_5_0_0_output_loss: 2.7487 - mask_5_0_1_output_loss: 2.7463 - mask_5_1_0_output_loss: 2.7510 - mask_5_1_1_output_loss: 2.7461 - mask_5_2_0_output_loss: 2.7519 - mask_5_2_1_output_loss: 2.7487 - mask_5_3_0_output_loss: 2.7514 - mask_5_3_1_output_loss: 2.7489 - mask_5_4_0_output_loss: 2.7498 - mask_5_4_1_output_loss: 2.7489 - mask_5_5_0_output_loss: 2.7484 - mask_5_5_1_output_loss: 2.7483 - mask_5_6_0_output_loss: 2.7453 - mask_5_6_1_output_loss: 2.7451 - block_perm_5_output_accuracy: 0.6358 - mask_5_0_0_output_accuracy: 0.0849 - mask_5_0_1_output_accuracy: 0.0869 - mask_5_1_0_output_accuracy: 0.0838 - mask_5_1_1_output_accuracy: 0.0863 - mask_5_2_0_output_accuracy: 0.0834 - mask_5_2_1_output_accuracy: 0.0856 - mask_5_3_0_output_accuracy: 0.0831 - mask_5_3_1_output_accuracy: 0.0853 - mask_5_4_0_output_accuracy: 0.0844 - mask_5_4_1_output_accuracy: 0.0848 - mask_5_5_0_output_accuracy: 0.0846 - mask_5_5_1_output_accuracy: 0.0853 - mask_5_6_0_output_accuracy: 0.0868 - mask_5_6_1_output_accuracy: 0.0865 - val_loss: 40.2255 - val_block_perm_5_output_loss: 1.4071 - val_mask_5_0_0_output_loss: 2.7496 - val_mask_5_0_1_output_loss: 2.8266 - val_mask_5_1_0_output_loss: 2.7565 - val_mask_5_1_1_output_loss: 2.7442 - val_mask_5_2_0_output_loss: 2.7570 - val_mask_5_2_1_output_loss: 2.7464 - val_mask_5_3_0_output_loss: 2.7499 - val_mask_5_3_1_output_loss: 2.7497 - val_mask_5_4_0_output_loss: 2.8904 - val_mask_5_4_1_output_loss: 2.7655 - val_mask_5_5_0_output_loss: 2.7436 - val_mask_5_5_1_output_loss: 2.7530 - val_mask_5_6_0_output_loss: 2.8027 - val_mask_5_6_1_output_loss: 2.7831 - val_block_perm_5_output_accuracy: 0.5489 - val_mask_5_0_0_output_accuracy: 0.0859 - val_mask_5_0_1_output_accuracy: 0.0701 - val_mask_5_1_0_output_accuracy: 0.0809 - val_mask_5_1_1_output_accuracy: 0.0869 - val_mask_5_2_0_output_accuracy: 0.0829 - val_mask_5_2_1_output_accuracy: 0.0861 - val_mask_5_3_0_output_accuracy: 0.0843 - val_mask_5_3_1_output_accuracy: 0.0842 - val_mask_5_4_0_output_accuracy: 0.0651 - val_mask_5_4_1_output_accuracy: 0.0820 - val_mask_5_5_0_output_accuracy: 0.0872 - val_mask_5_5_1_output_accuracy: 0.0853 - val_mask_5_6_0_output_accuracy: 0.0734 - val_mask_5_6_1_output_accuracy: 0.0790
# Epoch 5/1000
# 10547/10547 [==============================] - 2055s 195ms/step - loss: 39.4705 - block_perm_5_output_loss: 1.0567 - mask_5_0_0_output_loss: 2.7438 - mask_5_0_1_output_loss: 2.7402 - mask_5_1_0_output_loss: 2.7468 - mask_5_1_1_output_loss: 2.7412 - mask_5_2_0_output_loss: 2.7480 - mask_5_2_1_output_loss: 2.7440 - mask_5_3_0_output_loss: 2.7475 - mask_5_3_1_output_loss: 2.7443 - mask_5_4_0_output_loss: 2.7453 - mask_5_4_1_output_loss: 2.7433 - mask_5_5_0_output_loss: 2.7438 - mask_5_5_1_output_loss: 2.7427 - mask_5_6_0_output_loss: 2.7416 - mask_5_6_1_output_loss: 2.7413 - block_perm_5_output_accuracy: 0.6624 - mask_5_0_0_output_accuracy: 0.0875 - mask_5_0_1_output_accuracy: 0.0902 - mask_5_1_0_output_accuracy: 0.0858 - mask_5_1_1_output_accuracy: 0.0894 - mask_5_2_0_output_accuracy: 0.0855 - mask_5_2_1_output_accuracy: 0.0882 - mask_5_3_0_output_accuracy: 0.0855 - mask_5_3_1_output_accuracy: 0.0874 - mask_5_4_0_output_accuracy: 0.0866 - mask_5_4_1_output_accuracy: 0.0881 - mask_5_5_0_output_accuracy: 0.0869 - mask_5_5_1_output_accuracy: 0.0878 - mask_5_6_0_output_accuracy: 0.0881 - mask_5_6_1_output_accuracy: 0.0881 - val_loss: 41.7462 - val_block_perm_5_output_loss: 2.0034 - val_mask_5_0_0_output_loss: 2.7724 - val_mask_5_0_1_output_loss: 2.9516 - val_mask_5_1_0_output_loss: 2.7701 - val_mask_5_1_1_output_loss: 2.7492 - val_mask_5_2_0_output_loss: 2.8444 - val_mask_5_2_1_output_loss: 2.8158 - val_mask_5_3_0_output_loss: 2.8027 - val_mask_5_3_1_output_loss: 2.8546 - val_mask_5_4_0_output_loss: 2.7447 - val_mask_5_4_1_output_loss: 2.7460 - val_mask_5_5_0_output_loss: 2.8446 - val_mask_5_5_1_output_loss: 3.0220 - val_mask_5_6_0_output_loss: 2.8897 - val_mask_5_6_1_output_loss: 2.9351 - val_block_perm_5_output_accuracy: 0.3810 - val_mask_5_0_0_output_accuracy: 0.0798 - val_mask_5_0_1_output_accuracy: 0.0673 - val_mask_5_1_0_output_accuracy: 0.0777 - val_mask_5_1_1_output_accuracy: 0.0826 - val_mask_5_2_0_output_accuracy: 0.0694 - val_mask_5_2_1_output_accuracy: 0.0706 - val_mask_5_3_0_output_accuracy: 0.0710 - val_mask_5_3_1_output_accuracy: 0.0721 - val_mask_5_4_0_output_accuracy: 0.0861 - val_mask_5_4_1_output_accuracy: 0.0859 - val_mask_5_5_0_output_accuracy: 0.0664 - val_mask_5_5_1_output_accuracy: 0.0664 - val_mask_5_6_0_output_accuracy: 0.0666 - val_mask_5_6_1_output_accuracy: 0.0667
# Epoch 6/1000
#  1627/10547 [===>..........................] - ETA: 27:43 - loss: 39.4290 - block_perm_5_output_loss: 1.0343 - mask_5_0_0_output_loss: 2.7425 - mask_5_0_1_output_loss: 2.7385 - mask_5_1_0_output_loss: 2.7456 - mask_5_1_1_output_loss: 2.7407 - mask_5_2_0_output_loss: 2.7469 - mask_5_2_1_output_loss: 2.7426 - mask_5_3_0_output_loss: 2.7469 - mask_5_3_1_output_loss: 2.7431 - mask_5_4_0_output_loss: 2.7435 - mask_5_4_1_output_loss: 2.7407 - mask_5_5_0_output_loss: 2.7430 - mask_5_5_1_output_loss: 2.7407 - mask_5_6_0_output_loss: 2.7410 - mask_5_6_1_output_loss: 2.7391 - block_perm_5_output_accuracy: 0.6718 - mask_5_0_0_output_accuracy: 0.0861 - mask_5_0_1_output_accuracy: 0.0901 - mask_5_1_0_output_accuracy: 0.0873 - mask_5_1_1_output_accuracy: 0.0886 - mask_5_2_0_output_accuracy: 0.0856 - mask_5_2_1_output_accuracy: 0.0890 - mask_5_3_0_output_accuracy: 0.0847 - mask_5_3_1_output_accuracy: 0.0872 - mask_5_4_0_output_accuracy: 0.0877 - mask_5_4_1_output_accuracy: 0.0902 - mask_5_5_0_output_accuracy: 0.0861 - mask_5_5_1_output_accuracy: 0.0894 - mask_5_6_0_output_accuracy: 0.0887 - mask_5_6_1_output_accuracy: 0.0901
