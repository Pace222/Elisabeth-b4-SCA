# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "7"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning
# Out:
# 2024-06-17 14:56:50.760658: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-17 14:56:50.815864: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-17 14:56:51.742963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
if True:
    with open("splitted_rws.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
        X_training, X_val, X_extraction = X_training[:, 5075:9930], X_val[:, 5075:9930], X_extraction[:, 5075:9930]
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_rws_only.pic", "rb") as r:
        traces_rws_only = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_rws_only, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_rws.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_rws_1", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_rws_1.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_rws_1.keras")
except ValueError:
    pass
# Out:
# 2024-06-17 14:57:09.962261: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.005479: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.005543: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.018105: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.018182: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.018214: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.260890: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.260956: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.260967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-17 14:57:10.261009: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:db:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-17 14:57:10.261040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21742 MB memory:  -> device: 0, name: NVIDIA RTX 4500 Ada Generation, pci bus id: 0000:db:00.0, compute capability: 8.9

# %%
X_training = np.pad(X_training, ((0, 0), (resnet.model.input.shape[1] - X_training.shape[1], 0)))
X_val = np.pad(X_val, ((0, 0), (resnet.model.input.shape[1] - X_val.shape[1], 0)))

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
new_y_train = {}
new_y_val = {}
for output in train_gen.y.keys():
    idx = int(output[len('rws_mask_'):][:2])
    shx = int(output[len('rws_mask_XX_')])
    new_y_train[f'rws_mask_{idx - 24}_{shx}_output'] = train_gen.y[output]
    new_y_val[f'rws_mask_{idx - 24}_{shx}_output'] = val_gen.y[output]
train_gen.y = new_y_train
val_gen.y = new_y_val

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig
racy: 0.1090 - rws_mask_1_1_output_accuracy: 0.0933 - rws_mask_20_0_output_accuracy: 0.1102 - rws_mask_20_1_output_accuracy: 0.0934 - rws_mask_21_0_output_accuracy: 0.1092 - rws_mask_21_1_output_accuracy: 0.0929 - rws_mask_22_0_output_accuracy: 0.1106 - rws_mask_22_1_output_accuracy: 0.0921 - rws_mask_23_0_output_accuracy: 0.1049 - rws_mask_23_1_output_accuracy: 0.0884 - rws_mask_2_0_output_accuracy: 0.1088 - rws_mask_2_1_output_accuracy: 0.0930 - rws_mask_3_0_output_accuracy: 0.1079 - rws_mask_3_1_output_accuracy: 0.0945 - rws_mask_4_0_output_accuracy: 0.1113 - rws_mask_4_1_output_accuracy: 0.0947 - rws_mask_5_0_output_accuracy: 0.1098 - rws_mask_5_1_output_accuracy: 0.0931 - rws_mask_6_0_output_accuracy: 0.1104 - rws_mask_6_1_output_accuracy: 0.0946 - rws_mask_7_0_output_accuracy: 0.1102 - rws_mask_7_1_output_accuracy: 0.0938 - rws_mask_8_0_output_accuracy: 0.1073 - rws_mask_8_1_output_accuracy: 0.0935 - rws_mask_9_0_output_accuracy: 0.1120 - rws_mask_9_1_output_accuracy: 0.0943
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_rws_1.keras", patience=10)
#
# File ~/Pierugo/protected_side_channel_attack/deep_learning.py:552, in ResNetSCA.train_model_generator(self, X_y_gen_training, X_y_gen_val, save_file_name, patience)
#     549 # Early stopping callback
#     550 callbacks.append(EarlyStopping(monitor="val_loss", patience=patience, restore_best_weights=True))
# --> 552 history = self.model.fit(x=X_y_gen_training, verbose = 1, validation_data=X_y_gen_val, epochs=self.epochs, callbacks=callbacks)
#     553 return history
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:239, in _maybe_define_function(args, kwargs, tracing_options)
#     229 lookup_func_type, lookup_func_context = (
#     230     function_type_utils.make_canonicalized_monomorphic_type(
#     231         args,
#    (...)
#     235     )
#     236 )
#     238 if tracing_options.function_cache is not None:
# --> 239   concrete_function = tracing_options.function_cache.lookup(
#     240       lookup_func_type, current_func_context
#     241   )
#     242 else:
#     243   concrete_function = None
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:48, in FunctionCache.lookup(self, function_type, context)
#      46 context = context or FunctionContext()
#      47 if context in self._dispatch_dict:
# ---> 48   dispatch_type = self._dispatch_dict[context].dispatch(function_type)
#      49   if dispatch_type:
#      50     return self._primary[(context, dispatch_type)]
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/type_dispatch.py:80, in TypeDispatchTable.dispatch(self, request)
#      78 """Returns the most specific supertype target if it exists in the table."""
#      79 # For known exact matches.
# ---> 80 if request in self._dispatch_table:
#      81   return request
#      83 # For known non-exact matches.
#      84 # (self._dispatch cache does not contain exact matches)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:456, in FunctionType.__hash__(self)
#     455 def __hash__(self) -> int:
# --> 456   return hash((tuple(self.parameters.items()), tuple(self.captures.items())))
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:155, in Parameter.__hash__(self)
#     154 def __hash__(self):
# --> 155   return hash((self.name, self.kind, self.optional, self.type_constraint))
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:554, in TypeSpec.__hash__(self)
#     553 def __hash__(self) -> int:
# --> 554   return hash(self.__get_cmp_key())
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:605, in TypeSpec.__get_cmp_key(self)
#     601 """Returns a hashable eq-comparable key for `self`."""
#     602 if not hasattr(self, _CACHED_CMP_KEY):
#     603   setattr(self, _CACHED_CMP_KEY, (
#     604       type(self),
# --> 605       self.__make_cmp_key(self._serialize()),
#     606   ))
#     607 return getattr(self, _CACHED_CMP_KEY)
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:625, in TypeSpec.__make_cmp_key(self, value)
#     619   return tuple([
#     620       tuple([self.__make_cmp_key(key),
#     621              self.__make_cmp_key(value[key])])
#     622       for key in sorted(value.keys())
#     623   ])
#     624 if isinstance(value, tuple):
# --> 625   return tuple([self.__make_cmp_key(v) for v in value])
#     626 if isinstance(value, list):
#     627   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:625, in <listcomp>(.0)
#     619   return tuple([
#     620       tuple([self.__make_cmp_key(key),
#     621              self.__make_cmp_key(value[key])])
#     622       for key in sorted(value.keys())
#     623   ])
#     624 if isinstance(value, tuple):
# --> 625   return tuple([self.__make_cmp_key(v) for v in value])
#     626 if isinstance(value, list):
#     627   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:625, in TypeSpec.__make_cmp_key(self, value)
#     619   return tuple([
#     620       tuple([self.__make_cmp_key(key),
#     621              self.__make_cmp_key(value[key])])
#     622       for key in sorted(value.keys())
#     623   ])
#     624 if isinstance(value, tuple):
# --> 625   return tuple([self.__make_cmp_key(v) for v in value])
#     626 if isinstance(value, list):
#     627   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:625, in <listcomp>(.0)
#     619   return tuple([
#     620       tuple([self.__make_cmp_key(key),
#     621              self.__make_cmp_key(value[key])])
#     622       for key in sorted(value.keys())
#     623   ])
#     624 if isinstance(value, tuple):
# --> 625   return tuple([self.__make_cmp_key(v) for v in value])
#     626 if isinstance(value, list):
#     627   return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:619, in TypeSpec.__make_cmp_key(self, value)
#     617   return value
#     618 if isinstance(value, dict):
# --> 619   return tuple([
#     620       tuple([self.__make_cmp_key(key),
#     621              self.__make_cmp_key(value[key])])
#     622       for key in sorted(value.keys())
#     623   ])
#     624 if isinstance(value, tuple):
#     625   return tuple([self.__make_cmp_key(v) for v in value])
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:621, in <listcomp>(.0)
#     617   return value
#     618 if isinstance(value, dict):
#     619   return tuple([
#     620       tuple([self.__make_cmp_key(key),
# --> 621              self.__make_cmp_key(value[key])])
#     622       for key in sorted(value.keys())
#     623   ])
#     624 if isinstance(value, tuple):
#     625   return tuple([self.__make_cmp_key(v) for v in value])
#
# File ~/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:611, in TypeSpec.__make_cmp_key(self, value)
#     609 def __make_cmp_key(self, value):
#     610   """Converts `value` to a hashable key."""
# --> 611   if isinstance(value, (int, float, bool, np.generic, dtypes.DType, TypeSpec,
#     612                         tensor_shape.TensorShape)):
#     613     return value
#     614   if isinstance(value, compat.bytes_or_text_types):
#
# File /usr/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:
