# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import numpy as np
import pickle as pic

# %%
from tensorflow.keras.models import load_model
# Out:
# 2024-06-12 14:06:35.411782: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-12 14:06:35.469382: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 14:06:36.383887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with open("splitted_round_10.pic", "rb") as r:
    X_training, X_val, X_extraction = pic.load(r)

# %%
model = load_model("./resnet_models/resnet_750000_orig_round_10_adjusted.keras")
y_prediction = model.predict(X_extraction)
y_prediction = [np.log(pred) for pred in y_prediction]
# Out:
# 2024-06-12 14:06:44.005805: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 14:06:44.051023: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 14:06:44.051079: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 14:06:44.066057: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:1a:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
with open("y_extraction_750000_orig_round_10_adjusted.pic", "wb") as w:
    pic.dump(y_prediction, w)
