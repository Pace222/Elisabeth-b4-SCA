# %%
import os
os.environ['CUDA_DEVICE_ORDER'] = "PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = "5"

# %%
import numpy as np
import pickle as pic

from sklearn.model_selection import train_test_split

# %%
import deep_learning
# Out:
# 2024-06-12 12:07:39.542733: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-12 12:07:39.601998: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 12:07:40.599569: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
if True:
    with open("splitted_round_13.pic", "rb") as r:
        X_training, X_val, X_extraction = pic.load(r)
    with open("splitted_labels_1000000.pic", "rb") as r:
        y_training, y_val, y_extraction = pic.load(r)
else:
    with open("traces_round_13_adjusted_only.pic", "rb") as r:
        traces_round_13 = pic.load(r)
    with open("labels_1000000.pic", "rb") as r:
        rws_perms_labels, round_perms_labels, copy_perms_labels, rws_masks_labels, round_masks_labels = pic.load(r)

    X_total, y_total = deep_learning.prepare_data_dl(traces_round_13, round_perms_labels, copy_perms_labels, round_masks_labels, rws_perms_labels, rws_masks_labels)

    profile, test = train_test_split(np.arange(X_total.shape[0]), train_size=750_000, random_state=0)

    X_profiling, X_extraction = X_total[profile], X_total[test]
    train, val = train_test_split(np.arange(X_profiling.shape[0]), test_size=0.1, random_state=0)
    X_training, X_val = X_profiling[train], X_profiling[val]

    with open("splitted_round_13.pic", "wb") as w:
        pic.dump((X_training, X_val, X_extraction), w)

    if False:
        y_profiling = {}
        y_training = {}
        y_val = {}
        y_extraction = {}
        for label in y_total.keys():
            print(label, end="\r")
            y_profiling[label], y_extraction[label] = y_total[label][profile], y_total[label][test]
            y_training[label], y_val[label] = y_profiling[label][train], y_profiling[label][val]

        with open("splitted_labels_1000000.pic", "wb") as w:
            pic.dump((y_training, y_val, y_extraction), w)
    else:
        with open("splitted_labels_1000000.pic", "rb") as r:
            y_training, y_val, y_extraction = pic.load(r)

# %%
resnet = deep_learning.ResNetSCA(network="orig_round_13", epochs=1000, dataset_size=X_training.shape[0])
try:
    deep_learning.check_file_exists("./resnet_models/resnet_750000_orig_round_13_adjusted.keras")
    from tensorflow.keras.models import load_model
    resnet.model = load_model("./resnet_models/resnet_750000_orig_round_13_adjusted.keras")
except ValueError:
    pass
# Out:
# 2024-06-12 12:07:45.434147: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.485567: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.485619: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.503064: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.503135: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.503166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.722234: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.722358: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.722371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-06-12 12:07:45.722423: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:b2:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-06-12 12:07:45.722461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9057 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b2:00.0, compute capability: 7.5

# %%
train_gen = deep_learning.DataGenerator(X_training, y_training)
val_gen = deep_learning.DataGenerator(X_val, y_val)

# %%
history = resnet.train_model_generator(train_gen, val_gen, "./resnet_models/resnet_750000_orig_round_13_adjusted.keras", patience=10)
# Out:
# Epoch 1/1000
# 2024-06-12 12:08:20.903929: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# /root/Pierugo/protected_side_channel_attack/.venv_linux/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718186901.138968    5518 service.cc:145] XLA service 0x7fa368076540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1718186901.139021    5518 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-06-12 12:08:21.927204: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-12 12:08:24.611297: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-06-12 12:08:28.085654: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 12.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718186919.176380    5518 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_40', 120 bytes spill stores, 120 bytes spill loads
#
# I0000 00:00:1718186919.214935    5518 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#
13_0_0_output_accuracy: 0.0892 - val_mask_13_0_1_output_accuracy: 0.0933 - val_mask_13_1_0_output_accuracy: 0.0885 - val_mask_13_1_1_output_accuracy: 0.0907 - val_mask_13_2_0_output_accuracy: 0.0853 - val_mask_13_2_1_output_accuracy: 0.0926 - val_mask_13_3_0_output_accuracy: 0.0885 - val_mask_13_3_1_output_accuracy: 0.0911 - val_mask_13_4_0_output_accuracy: 0.0756 - val_mask_13_4_1_output_accuracy: 0.0785 - val_mask_13_5_0_output_accuracy: 0.0901 - val_mask_13_5_1_output_accuracy: 0.0926 - val_mask_13_6_0_output_accuracy: 0.0851 - val_mask_13_6_1_output_accuracy: 0.0911
# Epoch 5/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 649s 62ms/step - block_perm_13_output_accuracy: 0.7027 - loss: 39.1937 - mask_13_0_0_output_accuracy: 0.0926 - mask_13_0_1_output_accuracy: 0.0967 - mask_13_1_0_output_accuracy: 0.0903 - mask_13_1_1_output_accuracy: 0.0949 - mask_13_2_0_output_accuracy: 0.0900 - mask_13_2_1_output_accuracy: 0.0938 - mask_13_3_0_output_accuracy: 0.0910 - mask_13_3_1_output_accuracy: 0.0950 - mask_13_4_0_output_accuracy: 0.0915 - mask_13_4_1_output_accuracy: 0.0951 - mask_13_5_0_output_accuracy: 0.0899 - mask_13_5_1_output_accuracy: 0.0950 - mask_13_6_0_output_accuracy: 0.0921 - mask_13_6_1_output_accuracy: 0.0920 - val_block_perm_13_output_accuracy: 0.4957 - val_loss: 40.1423 - val_mask_13_0_0_output_accuracy: 0.0795 - val_mask_13_0_1_output_accuracy: 0.0776 - val_mask_13_1_0_output_accuracy: 0.0832 - val_mask_13_1_1_output_accuracy: 0.0852 - val_mask_13_2_0_output_accuracy: 0.0744 - val_mask_13_2_1_output_accuracy: 0.0783 - val_mask_13_3_0_output_accuracy: 0.0908 - val_mask_13_3_1_output_accuracy: 0.0881 - val_mask_13_4_0_output_accuracy: 0.0798 - val_mask_13_4_1_output_accuracy: 0.0822 - val_mask_13_5_0_output_accuracy: 0.0791 - val_mask_13_5_1_output_accuracy: 0.0777 - val_mask_13_6_0_output_accuracy: 0.0879 - val_mask_13_6_1_output_accuracy: 0.0899
# Epoch 6/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 650s 62ms/step - block_perm_13_output_accuracy: 0.7044 - loss: 39.1810 - mask_13_0_0_output_accuracy: 0.0937 - mask_13_0_1_output_accuracy: 0.0970 - mask_13_1_0_output_accuracy: 0.0897 - mask_13_1_1_output_accuracy: 0.0960 - mask_13_2_0_output_accuracy: 0.0904 - mask_13_2_1_output_accuracy: 0.0942 - mask_13_3_0_output_accuracy: 0.0910 - mask_13_3_1_output_accuracy: 0.0950 - mask_13_4_0_output_accuracy: 0.0914 - mask_13_4_1_output_accuracy: 0.0954 - mask_13_5_0_output_accuracy: 0.0908 - mask_13_5_1_output_accuracy: 0.0943 - mask_13_6_0_output_accuracy: 0.0919 - mask_13_6_1_output_accuracy: 0.0926 - val_block_perm_13_output_accuracy: 0.4716 - val_loss: 40.2710 - val_mask_13_0_0_output_accuracy: 0.0834 - val_mask_13_0_1_output_accuracy: 0.0769 - val_mask_13_1_0_output_accuracy: 0.0875 - val_mask_13_1_1_output_accuracy: 0.0926 - val_mask_13_2_0_output_accuracy: 0.0855 - val_mask_13_2_1_output_accuracy: 0.0882 - val_mask_13_3_0_output_accuracy: 0.0908 - val_mask_13_3_1_output_accuracy: 0.0908 - val_mask_13_4_0_output_accuracy: 0.0910 - val_mask_13_4_1_output_accuracy: 0.0905 - val_mask_13_5_0_output_accuracy: 0.0776 - val_mask_13_5_1_output_accuracy: 0.0879 - val_mask_13_6_0_output_accuracy: 0.0782 - val_mask_13_6_1_output_accuracy: 0.0732
# Epoch 7/1000
# 10547/10547 ━━━━━━━━━━━━━━━━━━━━ 648s 61ms/step - block_perm_13_output_accuracy: 0.7057 - loss: 39.1637 - mask_13_0_0_output_accuracy: 0.0924 - mask_13_0_1_output_accuracy: 0.0976 - mask_13_1_0_output_accuracy: 0.0901 - mask_13_1_1_output_accuracy: 0.0959 - mask_13_2_0_output_accuracy: 0.0900 - mask_13_2_1_output_accuracy: 0.0954 - mask_13_3_0_output_accuracy: 0.0908 - mask_13_3_1_output_accuracy: 0.0954 - mask_13_4_0_output_accuracy: 0.0922 - mask_13_4_1_output_accuracy: 0.0955 - mask_13_5_0_output_accuracy: 0.0902 - mask_13_5_1_output_accuracy: 0.0946 - mask_13_6_0_output_accuracy: 0.0923 - mask_13_6_1_output_accuracy: 0.0931 - val_block_perm_13_output_accuracy: 0.5898 - val_loss: 39.7870 - val_mask_13_0_0_output_accuracy: 0.0917 - val_mask_13_0_1_output_accuracy: 0.0957 - val_mask_13_1_0_output_accuracy: 0.0847 - val_mask_13_1_1_output_accuracy: 0.0864 - val_mask_13_2_0_output_accuracy: 0.0806 - val_mask_13_2_1_output_accuracy: 0.0904 - val_mask_13_3_0_output_accuracy: 0.0891 - val_mask_13_3_1_output_accuracy: 0.0915 - val_mask_13_4_0_output_accuracy: 0.0909 - val_mask_13_4_1_output_accuracy: 0.0918 - val_mask_13_5_0_output_accuracy: 0.0801 - val_mask_13_5_1_output_accuracy: 0.0778 - val_mask_13_6_0_output_accuracy: 0.0850 - val_mask_13_6_1_output_accuracy: 0.0811
# Epoch 8/1000
# 10278/10547 ━━━━━━━━━━━━━━━━━━━━ 16s 60ms/step - block_perm_13_output_accuracy: 0.7056 - loss: 39.1562 - mask_13_0_0_output_accuracy: 0.0927 - mask_13_0_1_output_accuracy: 0.0977 - mask_13_1_0_output_accuracy: 0.0899 - mask_13_1_1_output_accuracy: 0.0955 - mask_13_2_0_output_accuracy: 0.0910 - mask_13_2_1_output_accuracy: 0.0950 - mask_13_3_0_output_accuracy: 0.0909 - mask_13_3_1_output_accuracy: 0.0960 - mask_13_4_0_output_accuracy: 0.0925 - mask_13_4_1_output_accuracy: 0.0949 - mask_13_5_0_output_accuracy: 0.0908 - mask_13_5_1_output_accuracy: 0.0956 - mask_13_6_0_output_accuracy: 0.0917 - mask_13_6_1_output_accuracy: 0.0924
